# %% [markdown]
# ## EXPLORATIVE DATA ANALYSIS OF ONLINE RETAIL STORE

# %% [markdown]
# ### PROBLEM STATEMENT
# Perform customer behavioural to enhance customer retention and satisfaction
# of the online retail.

# %%
## IMPORT THE NECESSARY LIBRARIES
import numpy as np
import pandas as pd

# for visuals
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# import and read file
# Load and read file === csv, excel, json, 
df = pd.read_csv(r"C:\Users\USER\Downloads\Telegram Desktop\OnlineRetail.csv")
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#        InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 08:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 08:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 08:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 08:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 08:26       3.39     17850.0  United Kingdom

# %%
df.tail()
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899      CHILDREN'S APRON DOLLY GIRL         6
# 541906    581587     23254     CHILDRENS CUTLERY DOLLY GIRL         4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138     BAKING SET 9 PIECE RETROSPOT         3
#
#             InvoiceDate  UnitPrice  CustomerID Country
# 541904  12/9/2011 12:50       0.85     12680.0  France
# 541905  12/9/2011 12:50       2.10     12680.0  France
# 541906  12/9/2011 12:50       4.15     12680.0  France
# 541907  12/9/2011 12:50       4.15     12680.0  France
# 541908  12/9/2011 12:50       4.95     12680.0  France

# %%
# infor of the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
# shape of the data 
df.shape
# Out:
# (541909, 8)

# %%
# check for missing values
df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
# Visualise missing values
plt.figure(figsize = (10, 6))
sns.heatmap(df.isnull(), cbar = True, cmap = 'magma_r')
plt.title('Visualizing missing values')
plt.show()

# %%
# check columns
df.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
# check for negative values in 'unitprice'
negative_prices = df[df['UnitPrice']< 0]
negative_prices
# Out:
#        InvoiceNo StockCode      Description  Quantity      InvoiceDate  \
# 299983   A563186         B  Adjust bad debt         1  8/12/2011 14:51
# 299984   A563187         B  Adjust bad debt         1  8/12/2011 14:52
#
#         UnitPrice  CustomerID         Country
# 299983  -11062.06         NaN  United Kingdom
# 299984  -11062.06         NaN  United Kingdom

# %%
# check the data types
df.dtypes
# Out:
# InvoiceNo       object
# StockCode       object
# Description     object
# Quantity         int64
# InvoiceDate     object
# UnitPrice      float64
# CustomerID     float64
# Country         object
# dtype: object

# %% [markdown]
# ## Data  Manipulation and Validation
# - We will handle the missing values for `Description` and `CustomerID` by using the ffill method to replace the null values in `description`, and replace the null values with `unknown` respectively.
#
# - We will replace negative values in `UnitPrice` with `0` and replace the negative values in `Quantity` with the `weighted median` of Quantity.
#
# - We will additional column called `Revenue` by multiplying the `UnitPrice` by `Quantity`
#
# - We will convert the `InvoiceDate` to a `datetime` data type
#
# - We will convert the `CustomerID` from float to object/string data types
#
# - We will replace the country 'RSA' and 'EIRA' with 'South Africa' and 'Ireland'

# %%
# check the columns that are categorical and numerical
numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns.tolist()
numerical_cols
# Out:
# ['Quantity', 'UnitPrice', 'CustomerID']

# %%
categorical_cols = df.select_dtypes(include=['object', 'category']).columns.tolist()
categorical_cols
# Out:
# ['InvoiceNo', 'StockCode', 'Description', 'InvoiceDate', 'Country']

# %%
# value counts for categorical variables
for column in categorical_cols:
    print(df[column].value_counts())
# Out:
# 573585     1114
# 581219      749
# 581492      731
# 580729      721
# 558475      705
#            ...
# 554023        1
# 554022        1
# 554021        1
# 554020        1
# C558901       1
# Name: InvoiceNo, Length: 25900, dtype: int64
# 85123A    2313
# 22423     2203
# 85099B    2159
# 47566     1727
# 20725     1639
#           ...
# 21431        1
# 22275        1
# 17001        1
# 90187A       1
# 72759        1
# Name: StockCode, Length: 4070, dtype: int64
# WHITE HANGING HEART T-LIGHT HOLDER    2369
# REGENCY CAKESTAND 3 TIER              2200
# JUMBO BAG RED RETROSPOT               2159
# PARTY BUNTING                         1727
# LUNCH BAG RED RETROSPOT               1638
#                                       ...
# stock creditted wrongly                  1
# MARIE ANTOIENETT TRINKET BOX GOLD        1
# label mix up                             1
# DOORKNOB CERAMIC IVORY                   1
# SET OF 3 PINK FLYING DUCKS               1
# Name: Description, Length: 4211, dtype: int64
# 10/31/2011 14:41    1114
# 12/8/2011 09:28      749
# 12/9/2011 10:03      731
# 12/5/2011 17:24      721
# 6/29/2011 15:58      705
#                     ...
# 9/28/2011 9:57         1
# 9/28/2011 9:45         1
# 3/16/2011 12:13        1
# 3/16/2011 12:22        1
# 3/16/2011 15:58        1
# Name: InvoiceDate, Length: 23260, dtype: int64
# United Kingdom          495478
# Germany                   9495
# France                    8557
# EIRE                      8196
# Spain                     2533
# Netherlands               2371
# Belgium                   2069
# Switzerland               2002
# Portugal                  1519
# Australia                 1259
# Norway                    1086
# Italy                      803
# Channel Islands            758
# Finland                    695
# Cyprus                     622
# Sweden                     462
# Unspecified                446
# Austria                    401
# Denmark                    389
# Japan                      358
# Poland                     341
# Israel                     297
# USA                        291
# Hong Kong                  288
# Singapore                  229
# Iceland                    182
# Canada                     151
# Greece                     146
# Malta                      127
# United Arab Emirates        68
# European Community          61
# RSA                         58
# Lebanon                     45
# Lithuania                   35
# Brazil                      32
# Czech Republic              30
# Bahrain                     19
# Saudi Arabia                10
# Name: Country, dtype: int64

# %%
# value counts for numerical columns 
for column in numerical_cols:
    print(df[column].value_counts())
# Out:
#  1        148227
#  2         81829
#  12        61063
#  6         40868
#  4         38484
#            ...
# -472           1
# -161           1
# -1206          1
# -272           1
# -80995         1
# Name: Quantity, Length: 722, dtype: int64
# 1.25      50496
# 1.65      38181
# 0.85      28497
# 2.95      27768
# 0.42      24533
#           ...
# 84.21         1
# 46.86         1
# 28.66         1
# 156.45        1
# 224.69        1
# Name: UnitPrice, Length: 1630, dtype: int64
# 17841.0    7983
# 14911.0    5903
# 14096.0    5128
# 12748.0    4642
# 14606.0    2782
#            ...
# 15070.0       1
# 15753.0       1
# 17065.0       1
# 16881.0       1
# 16995.0       1
# Name: CustomerID, Length: 4372, dtype: int64

# %% [markdown]
# ##  Manipulation and Validation of Categorical columns

# %%
# manipulation & validation of categorical columns 
df['Country'] = df['Country'].replace(['RSA', 'EIRE'], ['South Africa', 'Ireland'])
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])
df['Description'].fillna(df['Description'].mode()[0], inplace=True)

# %%
df['InvoiceDate'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 541909 entries, 0 to 541908
# Series name: InvoiceDate
# Non-Null Count   Dtype
# --------------   -----
# 541909 non-null  datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 4.1 MB

# %%
# to check if the 'RSA' has been replaced by 'South Africa'
df[df['Country'] == 'South Africa'].head()
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 395472    571035     21238                RED RETROSPOT CUP         8
# 395473    571035     21243             PINK  POLKADOT PLATE         8
# 395474    571035     23240  SET OF 4 KNICK KNACK TINS DOILY         6
# 395475    571035     23209          LUNCH BAG VINTAGE DOILY        10
# 395476    571035     23201               JUMBO BAG ALPHABET        10
#
#                InvoiceDate  UnitPrice  CustomerID       Country
# 395472 2011-10-13 12:50:00       0.85     12446.0  South Africa
# 395473 2011-10-13 12:50:00       1.69     12446.0  South Africa
# 395474 2011-10-13 12:50:00       4.15     12446.0  South Africa
# 395475 2011-10-13 12:50:00       1.65     12446.0  South Africa
# 395476 2011-10-13 12:50:00       2.08     12446.0  South Africa

# %%
# to check if the 'EIRE' has been replaced by 'Ireland'
df[df['Country'] == 'Ireland'].head()
# Out:
#      InvoiceNo StockCode                          Description  Quantity  \
# 1404    536540     22968            ROSE COTTAGE KEEPSAKE BOX         4
# 1405    536540    85071A  BLUE CHARLIE+LOLA PERSONAL DOORSIGN         6
# 1406    536540    85071C    CHARLIE+LOLA"EXTREMELY BUSY" SIGN         6
# 1407    536540     22355            CHARLOTTE BAG SUKI DESIGN        50
# 1408    536540     21579      LOLITA  DESIGN  COTTON TOTE BAG         6
#
#              InvoiceDate  UnitPrice  CustomerID  Country
# 1404 2010-12-01 14:05:00       9.95     14911.0  Ireland
# 1405 2010-12-01 14:05:00       2.95     14911.0  Ireland
# 1406 2010-12-01 14:05:00       2.55     14911.0  Ireland
# 1407 2010-12-01 14:05:00       0.85     14911.0  Ireland
# 1408 2010-12-01 14:05:00       2.25     14911.0  Ireland

# %%
# to check if there is missing values in 'Description'
df['Description'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ##  Manipulation and Validation of numerical columns

# %%
# convert the CustomerID from float to string, and fill the missing values with 'Unknown'
df['CustomerID'] = df['CustomerID'].astype(str).fillna('Unknown')

# replace the negative values in UnitPrice with 0
df['UnitPrice'] = np.where(df['UnitPrice'] < 0, 0, df['UnitPrice'])

#To replace the negative values in the Quantity column with the median of the column
median_quantity = df['Quantity'].median()
df['Quantity'] = df['Quantity'].apply(lambda x: median_quantity if x < 0 else x)

# create a new
# create a new column called 'Revenue' using 'UnitPrice' * 'Quantity'
df['Revenue'] = df['UnitPrice'] * df['Quantity']
# confirm the data types
df.info()
# replace 'nan' with 'Unknown'
df['CustomerID'] = df['CustomerID'].replace('nan','Unknown')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 9 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  541909 non-null  object
#  3   Quantity     541909 non-null  float64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   541909 non-null  object
#  7   Country      541909 non-null  object
#  8   Revenue      541909 non-null  float64
# dtypes: datetime64[ns](1), float64(3), object(5)
# memory usage: 37.2+ MB

# %%
# to check if the 'nan' has been replaced by 'Unknown'
df[df['CustomerID'] == 'Unknown']
# Out:
#        InvoiceNo StockCode                         Description  Quantity  \
# 622       536414     22139  WHITE HANGING HEART T-LIGHT HOLDER      56.0
# 1443      536544     21773     DECORATIVE ROSE BATHROOM BOTTLE       1.0
# 1444      536544     21774     DECORATIVE CATS BATHROOM BOTTLE       2.0
# 1445      536544     21786                   POLKADOT RAIN HAT       4.0
# 1446      536544     21787               RAIN PONCHO RETROSPOT       2.0
# ...          ...       ...                                 ...       ...
# 541536    581498    85099B             JUMBO BAG RED RETROSPOT       5.0
# 541537    581498    85099C      JUMBO  BAG BAROQUE BLACK WHITE       4.0
# 541538    581498     85150       LADIES & GENTLEMEN METAL SIGN       1.0
# 541539    581498     85174                   S/4 CACTI CANDLES       1.0
# 541540    581498       DOT                      DOTCOM POSTAGE       1.0
#
#                InvoiceDate  UnitPrice CustomerID         Country  Revenue
# 622    2010-12-01 11:52:00       0.00    Unknown  United Kingdom     0.00
# 1443   2010-12-01 14:32:00       2.51    Unknown  United Kingdom     2.51
# 1444   2010-12-01 14:32:00       2.51    Unknown  United Kingdom     5.02
# 1445   2010-12-01 14:32:00       0.85    Unknown  United Kingdom     3.40
# 1446   2010-12-01 14:32:00       1.66    Unknown  United Kingdom     3.32
# ...                    ...        ...        ...             ...      ...
# 541536 2011-12-09 10:26:00       4.13    Unknown  United Kingdom    20.65
# 541537 2011-12-09 10:26:00       4.13    Unknown  United Kingdom    16.52
# 541538 2011-12-09 10:26:00       4.96    Unknown  United Kingdom     4.96
# 541539 2011-12-09 10:26:00      10.79    Unknown  United Kingdom    10.79
# 541540 2011-12-09 10:26:00    1714.17    Unknown  United Kingdom  1714.17
#
# [135080 rows x 9 columns]

# %%
df['CustomerID'].value_counts()
# Out:
# Unknown    135080
# 17841.0      7983
# 14911.0      5903
# 14096.0      5128
# 12748.0      4642
#             ...
# 13270.0         1
# 17763.0         1
# 17291.0         1
# 15668.0         1
# 15562.0         1
# Name: CustomerID, Length: 4373, dtype: int64

# %%
# confirm if the negative values in 'UnitPrice' is replaced
df[df['UnitPrice'] < 0]
# Out:
# Empty DataFrame
# Columns: [InvoiceNo, StockCode, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country, Revenue]
# Index: []

# %%
# confirm if the negative values in 'Quantity' is replaced
df[df['Quantity'] < 0]
# Out:
# Empty DataFrame
# Columns: [InvoiceNo, StockCode, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country, Revenue]
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 9 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  541909 non-null  object
#  3   Quantity     541909 non-null  float64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   541909 non-null  object
#  7   Country      541909 non-null  object
#  8   Revenue      541909 non-null  float64
# dtypes: datetime64[ns](1), float64(3), object(5)
# memory usage: 37.2+ MB

# %% [markdown]
# ## Exploratory Data Analysis

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER       6.0
# 1    536365     71053                  WHITE METAL LANTERN       6.0
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER       8.0
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE       6.0
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.       6.0
#
#           InvoiceDate  UnitPrice CustomerID         Country  Revenue
# 0 2010-12-01 08:26:00       2.55    17850.0  United Kingdom    15.30
# 1 2010-12-01 08:26:00       3.39    17850.0  United Kingdom    20.34
# 2 2010-12-01 08:26:00       2.75    17850.0  United Kingdom    22.00
# 3 2010-12-01 08:26:00       3.39    17850.0  United Kingdom    20.34
# 4 2010-12-01 08:26:00       3.39    17850.0  United Kingdom    20.34

# %% [markdown]
# # Univariates Analysis

# %%
# Count the number of unique invoices
num_unique_invoices = df['InvoiceNo'].nunique()

# Print the results
print("Number of unique invoices:", num_unique_invoices)
# Out:
# Number of unique invoices: 25900

# %% [markdown]
# ### OBSERVATION
#
# There are 25,900 unique invoices in the dataset.

# %%
# Count the number of unique descriptions
num_unique_descriptions = df['Description'].nunique()

# Print the results
print("Number of unique descriptions:", num_unique_descriptions)
# Out:
# Number of unique descriptions: 4211

# %% [markdown]
# ###  OBSERVATION
#
# There are 4211 unique Product Description in the dataset.

# %%
# Calculate summary statistics for the 'Quantity' column
quantity_summary = df['Quantity'].describe()

# Calculate the mode of the 'Quantity' column
quantity_mode = df['Quantity'].mode()

# Print the results
print("Quantity summary statistics:")
print(quantity_summary)
print("Quantity mode:", quantity_mode)
# Out:
# Quantity summary statistics:
# count    541909.000000
# mean         10.505183
# std         155.289026
# min           1.000000
# 25%           1.000000
# 50%           3.000000
# 75%          10.000000
# max       80995.000000
# Name: Quantity, dtype: float64
# Quantity mode: 0    1.0
# Name: Quantity, dtype: float64

# %% [markdown]
# ### OBSERVATION
#
# The analysis revealed that the store had a total of 541,909 sales transactions. On average, each transaction involved a quantity of 10.505183 items sold. However, the standard deviation was quite high at 155.289026, indicating a large variation in the quantity of items sold across transactions.
#
# The minimum quantity sold was 1, while the maximum was an astonishing 80,995 items sold in a single transaction. The quartiles showed that 25% of transactions involved the sale of only one item, while 50% of transactions involved three or fewer items sold. The top 25% of transactions involved the sale of ten or more items.
#
# The quantity mode was one, indicating that the most commonly occurring quantity sold was one item. This finding suggests that the majority of transactions involved the sale of a small number of items.

# %%
# Count the number of unique customers
num_unique_customers = df['CustomerID'].nunique()

# Calculate summary statistics for the 'CustomerID' column
customer_summary = df['CustomerID'].describe()

# Calculate the mode of the 'CustomerID' column
customer_mode = df['CustomerID'].mode()

# Print the results
print("Number of unique customers:", num_unique_customers)

print("Customer summary statistics:")
print(customer_summary)
print("Customer mode:", customer_mode)
# Out:
# Number of unique customers: 4373
# Customer summary statistics:
# count      541909
# unique       4373
# top       Unknown
# freq       135080
# Name: CustomerID, dtype: object
# Customer mode: 0    Unknown
# Name: CustomerID, dtype: object

# %% [markdown]
# ### OBSERVATION
#
# The analysis revealed that the online store had a total of 541,909 sales transactions. However, the number of unique customers was only 4,373, indicating that some customers made multiple purchases.
# The customer summary statistics showed that the most common customer ID was "Unknown," with a frequency of 135,080. This finding suggested that a significant percentage of customers did not provide their customer ID when making purchases.

# %%
# Count the number of unique countries
num_unique_countries = df['Country'].nunique()

# Print the results
print("Number of unique countries:", num_unique_countries)
# Out:
# Number of unique countries: 38

# %% [markdown]
# ####  There are 38 unique Countries in the dataset.

# %% [markdown]
# ## Bivariates Analysis

# %%
# identify which items are frequently sold in large or small quantities.
# Group the data by StockCode and calculate the total Quantity for each group
stockcode_quantity = df.groupby('StockCode')['Quantity'].sum()

# Print the results
print("Total quantity sold for each StockCode:")
print(stockcode_quantity)
# Out:
# Total quantity sold for each StockCode:
# StockCode
# 10002           1043.0
# 10080            495.0
# 10120            193.0
# 10123C             8.0
# 10123G             3.0
#                  ...
# gift_0001_20      20.0
# gift_0001_30      37.0
# gift_0001_40       3.0
# gift_0001_50       4.0
# m                  1.0
# Name: Quantity, Length: 4070, dtype: float64

# %% [markdown]
# ###  OBSERVATION
#
# The analysis revealed that some StockCodes had much higher sales than others. For example, StockCode 10002 had a total quantity sold of 1043.0, indicating that this product was in high demand among customers. Similarly, StockCode 10080 had a total quantity sold of 495.0, indicating that this product was also popular among customers.
#
# On the other hand, some StockCodes had very low sales. For example, StockCode 10123G had a total quantity sold of only 3.0, indicating that this product was not very popular among customers. Similarly, StockCode M had a total quantity sold of only 1.0, indicating that this product was not selling well at all.

# %%
# Load the sales data into a pandas DataFrame
sales_data = pd.read_csv(r"C:\Users\USER\Downloads\Telegram Desktop\OnlineRetail.csv", usecols=['InvoiceNo', 'Description', 'Quantity'])

# Filter the DataFrame to only include transactions with negative quantities (returns)
returns_data = sales_data[sales_data['Quantity'] < 0]

# Loop through the returns data and print out the relevant information for each transaction
for index, row in returns_data.iterrows():
    if row['InvoiceNo'][0] == 'C':
        # This is a return transaction, so print out the relevant information
        print(f"InvoiceNo {row['InvoiceNo']} had a total quantity returned of {-row['Quantity']} items.")
        print(f"Description: {row['Description']}")
# Out:
# InvoiceNo C536379 had a total quantity returned of 1 items.
# Description: Discount
# InvoiceNo C536383 had a total quantity returned of 1 items.
# Description: SET OF 3 COLOURED  FLYING DUCKS
# InvoiceNo C536391 had a total quantity returned of 12 items.
# Description: PLASTERS IN TIN CIRCUS PARADE
# InvoiceNo C536391 had a total quantity returned of 24 items.
# Description: PACK OF 12 PINK PAISLEY TISSUES
# InvoiceNo C536391 had a total quantity returned of 24 items.
# Description: PACK OF 12 BLUE PAISLEY TISSUES
# InvoiceNo C536391 had a total quantity returned of 24 items.
# Description: PACK OF 12 RED RETROSPOT TISSUES
# InvoiceNo C536391 had a total quantity returned of 12 items.
# Description: CHICK GREY HOT WATER BOTTLE
# InvoiceNo C536391 had a total quantity returned of 12 items.
# Description: PLASTERS IN TIN VINTAGE PAISLEY
# InvoiceNo C536391 had a total quantity returned of 24 items.
# Description: PLASTERS IN TIN SKULLS
# InvoiceNo C536506 had a total quantity returned of 6 items.
# Description: JAM MAKING SET WITH JARS
# InvoiceNo C536543 had a total quantity returned of 1 items.
# Description: HAND WARMER RED RETROSPOT
# InvoiceNo C536543 had a total quantity returned of 2 items.
# Description: CHARLOTTE BAG SUKI DESIGN
# InvoiceNo C536548 had a total quantity returned of 4 items.
# Description: 3 HOOK HANGER MAGIC GARDEN
# InvoiceNo C536548 had a total quantity returned of 5 items.
# Description: 5 HOOK HANGER MAGIC TOADSTOOL
# InvoiceNo C536548 had a total quantity returned of 1 items.
# Description: SET/5 RED RETROSPOT LID GLASS BOWLS
# InvoiceNo C536548 had a total quantity returned of 7 items.
# Description: SET OF SALT AND PEPPER TOADSTOOLS
# InvoiceNo C536548 had a total quantity returned of 1 items.
# Description: DELUXE SEWING KIT
# InvoiceNo C536548 had a total quantity returned of 2 items.
# Description: TRIPLE PHOTO FRAME CORNICE
# InvoiceNo C536548 had a total quantity returned of 1 items.
# Description: RETROSPOT PARTY BAG + STICKER SET
# InvoiceNo C536548 had a total quantity returned of 2 items.
# Description: HOOK, 1 HANGER ,MAGIC GARDEN
# InvoiceNo C536548 had a total quantity returned of 6 items.
# Description: 6 RIBBONS RUSTIC CHARM
# InvoiceNo C536548 had a total quantity returned of 1 items.
# Description: CIRCUS PARADE LUNCH BOX
# InvoiceNo C536548 had a total quantity returned of 2 items.
# Description: ORGANISER WOOD ANTIQUE WHITE
# InvoiceNo C536548 had a total quantity returned of 3 items.
# Description: RED SPOTTY BISCUIT TIN
# InvoiceNo C536548 had a total quantity returned of 1 items.
# Description: PORCELAIN HANGING BELL SMALL
# InvoiceNo C536548 had a total quantity returned of 4 items.
# Description: ADVENT CALENDAR GINGHAM SACK
# InvoiceNo C536606 had a total quantity returned of 2 items.
# Description: SET/5 RED RETROSPOT LID GLASS BOWLS
# InvoiceNo C536622 had a total quantity returned of 2 items.
# Description: SET 7 BABUSHKA NESTING BOXES
# InvoiceNo C536625 had a total quantity returned of 2 items.
# Description: 3 TIER CAKE TIN GREEN AND CREAM
# InvoiceNo C536642 had a total quantity returned of 1 items.
# Description: MIRRORED DISCO BALL
# InvoiceNo C536734 had a total quantity returned of 4 items.
# Description: LIGHT GARLAND BUTTERFILES PINK
# InvoiceNo C536734 had a total quantity returned of 1 items.
# Description: 15CM CHRISTMAS GLASS BALL 20 LIGHTS
# InvoiceNo C536737 had a total quantity returned of 2 items.
# Description: ANTIQUE GLASS DRESSING TABLE POT
# InvoiceNo C536757 had a total quantity returned of 9360 items.
# Description: ROTATING SILVER ANGELS T-LIGHT HLDR
# InvoiceNo C536758 had a total quantity returned of 1 items.
# Description: SMALL GLASS HEART TRINKET POT
# InvoiceNo C536760 had a total quantity returned of 1 items.
# Description: PINK OWL SOFT TOY
# InvoiceNo C536760 had a total quantity returned of 3 items.
# Description: FELTCRAFT DOLL MOLLY
# InvoiceNo C536807 had a total quantity returned of 2 items.
# Description: PICNIC BASKET WICKER LARGE
# InvoiceNo C536807 had a total quantity returned of 1 items.
# Description: GLASS CLOCHE SMALL
# InvoiceNo C536812 had a total quantity returned of 36 items.
# Description: WOODEN STAR CHRISTMAS SCANDINAVIAN
# InvoiceNo C536812 had a total quantity returned of 192 items.
# Description: HEART WOODEN CHRISTMAS DECORATION
# InvoiceNo C536812 had a total quantity returned of 144 items.
# Description: CHRISTMAS GINGHAM STAR
# InvoiceNo C536812 had a total quantity returned of 144 items.
# Description: CHRISTMAS GINGHAM HEART
# InvoiceNo C536812 had a total quantity returned of 192 items.
# Description: CARD HOLDER GINGHAM HEART
# InvoiceNo C536812 had a total quantity returned of 144 items.
# Description: PARTY CONE CHRISTMAS DECORATION
# InvoiceNo C536814 had a total quantity returned of 2 items.
# Description: RED RETROSPOT TRADITIONAL TEAPOT
# InvoiceNo C536814 had a total quantity returned of 6 items.
# Description: IVORY PILLAR CANDLE SILVER FLOCK
# InvoiceNo C536814 had a total quantity returned of 2 items.
# Description: CREAM SWEETHEART MINI CHEST
# InvoiceNo C536814 had a total quantity returned of 12 items.
# Description: KINGS CHOICE GIANT TUBE MATCHES
# InvoiceNo C536814 had a total quantity returned of 1 items.
# Description: VICTORIAN SEWING BOX LARGE
# InvoiceNo C536815 had a total quantity returned of 1 items.
# Description: CACTI T-LIGHT CANDLES
# InvoiceNo C536815 had a total quantity returned of 1 items.
# Description: VICTORIAN GLASS HANGING T-LIGHT
# InvoiceNo C536816 had a total quantity returned of 2 items.
# Description: SILVER FISHING GNOME
# InvoiceNo C536817 had a total quantity returned of 1 items.
# Description: GREEN CHRISTMAS TREE CARD HOLDER
# InvoiceNo C536817 had a total quantity returned of 1 items.
# Description: COLOUR GLASS. STAR T-LIGHT HOLDER
# InvoiceNo C536818 had a total quantity returned of 1 items.
# Description: ANTIQUE SILVER TEA GLASS ENGRAVED
# InvoiceNo C536820 had a total quantity returned of 1 items.
# Description: NUMBER TILE COTTAGE GARDEN 9
# InvoiceNo C536820 had a total quantity returned of 1 items.
# Description: NUMBER TILE COTTAGE GARDEN 1
# InvoiceNo C536820 had a total quantity returned of 1 items.
# Description: NUMBER TILE COTTAGE GARDEN No
# InvoiceNo C536820 had a total quantity returned of 1 items.
# Description: RED RETROSPOT CAKE STAND
# InvoiceNo C536822 had a total quantity returned of 2 items.
# Description: BREAD BIN DINER STYLE IVORY
# InvoiceNo C536822 had a total quantity returned of 1 items.
# Description: SET/3 RED GINGHAM ROSE STORAGE BOX
# InvoiceNo C536825 had a total quantity returned of 1 items.
# Description: BAKING SET SPACEBOY DESIGN
# InvoiceNo C536825 had a total quantity returned of 2 items.
# Description: SMALL POPCORN HOLDER
# InvoiceNo C536826 had a total quantity returned of 2 items.
# Description: SET OF 3 BLACK FLYING DUCKS
# InvoiceNo C536826 had a total quantity returned of 3 items.
# Description: SET OF 3 BLACK FLYING DUCKS
# InvoiceNo C536827 had a total quantity returned of 3 items.
# Description: RED RETROSPOT TRADITIONAL TEAPOT
# InvoiceNo C536828 had a total quantity returned of 1 items.
# Description: BROCANTE SHELF WITH HOOKS
# InvoiceNo C536828 had a total quantity returned of 3 items.
# Description: ANTIQUE SILVER TEA GLASS ETCHED
# InvoiceNo C536829 had a total quantity returned of 1 items.
# Description: COLOUR GLASS. STAR T-LIGHT HOLDER
# InvoiceNo C536850 had a total quantity returned of 48 items.
# Description: CHRISTMAS LIGHTS 10 SANTAS
# InvoiceNo C536850 had a total quantity returned of 50 items.
# Description: DOORMAT MERRY CHRISTMAS RED
# InvoiceNo C536850 had a total quantity returned of 50 items.
# Description: CARDHOLDER GINGHAM CHRISTMAS TREE
# InvoiceNo C536850 had a total quantity returned of 48 items.
# Description: ADVENT CALENDAR GINGHAM SACK
# InvoiceNo C536850 had a total quantity returned of 48 items.
# Description: RED STAR CARD HOLDER
# InvoiceNo C536853 had a total quantity returned of 1 items.
# Description: CLASSICAL ROSE SMALL VASE
# InvoiceNo C536854 had a total quantity returned of 1 items.
# Description: 3 HEARTS HANGING DECORATION RUSTIC
# InvoiceNo C536854 had a total quantity returned of 1 items.
# Description: CHRISTMAS METAL POSTCARD WITH BELLS
# InvoiceNo C536854 had a total quantity returned of 1 items.
# Description: SAVE THE PLANET MUG
# InvoiceNo C536855 had a total quantity returned of 4 items.
# Description: RED RETROSPOT TRADITIONAL TEAPOT
# InvoiceNo C536978 had a total quantity returned of 1 items.
# Description: SWEETHEART CAKESTAND 3 TIER
# InvoiceNo C536979 had a total quantity returned of 1 items.
# Description: BEACH HUT KEY CABINET
# InvoiceNo C536979 had a total quantity returned of 1 items.
# Description: DOLLY GIRL LUNCH BOX
# InvoiceNo C537024 had a total quantity returned of 36 items.
# Description: HANGING BAUBLE T-LIGHT HOLDER SMALL
# InvoiceNo C537039 had a total quantity returned of 1 items.
# Description: CREAM SWEETHEART EGG HOLDER
# InvoiceNo C537039 had a total quantity returned of 1 items.
# Description: FORKED CACTUS CANDLE
# InvoiceNo C537039 had a total quantity returned of 1 items.
# Description: CACTI T-LIGHT CANDLES
# InvoiceNo C537043 had a total quantity returned of 6 items.
# Description: METAL MERRY CHRISTMAS WREATH
# InvoiceNo C537043 had a total quantity returned of 1 items.
# Description: ASSTD DESIGN RACING CAR PEN
# InvoiceNo C537132 had a total quantity returned of 2 items.
# Description: BROCANTE COAT RACK
# InvoiceNo C537132 had a total quantity returned of 1 items.
# Description: CAKE STAND VICTORIAN FILIGREE LARGE
# InvoiceNo C537132 had a total quantity returned of 2 items.
# Description: PINK GLASS CANDLEHOLDER
# InvoiceNo C537132 had a total quantity returned of 2 items.
# Description: CHEST 7 DRAWER MA CAMPAGNE
# InvoiceNo C537132 had a total quantity returned of 8 items.
# Description: CHALKBOARD KITCHEN ORGANISER
# InvoiceNo C537132 had a total quantity returned of 3 items.
# Description: CUPBOARD 3 DRAWER MA CAMPAGNE
# InvoiceNo C537143 had a total quantity returned of 1 items.
# Description: DOORMAT RED RETROSPOT
# InvoiceNo C537157 had a total quantity returned of 24 items.
# Description: FOLKART STAR CHRISTMAS DECORATIONS
# InvoiceNo C537164 had a total quantity returned of 1 items.
# Description: Discount
# InvoiceNo C537203 had a total quantity returned of 1 items.
# Description: CERAMIC CAKE STAND + HANGING CAKES
# InvoiceNo C537203 had a total quantity returned of 1 items.
# Description: WOODLAND STORAGE BOX LARGE
# InvoiceNo C537232 had a total quantity returned of 2 items.
# Description: SWEETHEART CARRY-ALL BASKET
# InvoiceNo C537234 had a total quantity returned of 20 items.
# Description: BUTTON BOX
# InvoiceNo C537251 had a total quantity returned of 2 items.
# Description: ENAMEL MEASURING JUG CREAM
# InvoiceNo C537251 had a total quantity returned of 8 items.
# Description: 4 TRADITIONAL SPINNING TOPS
# InvoiceNo C537251 had a total quantity returned of 2 items.
# Description: S/6 WOODEN SKITTLES IN COTTON BAG
# InvoiceNo C537251 had a total quantity returned of 5 items.
# Description: ALPHABET STENCIL CRAFT
# InvoiceNo C537251 had a total quantity returned of 3 items.
# Description: TRADITIONAL WOODEN SKIPPING ROPE
# InvoiceNo C537251 had a total quantity returned of 6 items.
# Description: POPPY'S PLAYHOUSE BATHROOM
# InvoiceNo C537251 had a total quantity returned of 8 items.
# Description: MEASURING TAPE BABUSHKA RED
# InvoiceNo C537251 had a total quantity returned of 4 items.
# Description: ROUND SNACK BOXES SET OF 4 SKULLS
# InvoiceNo C537251 had a total quantity returned of 4 items.
# Description: RED  HARMONICA IN BOX
# InvoiceNo C537251 had a total quantity returned of 9 items.
# Description: ROTATING SILVER ANGELS T-LIGHT HLDR
# InvoiceNo C537251 had a total quantity returned of 4 items.
# Description: POPPY'S PLAYHOUSE KITCHEN
# InvoiceNo C537251 had a total quantity returned of 6 items.
# Description: CHRISTMAS LIGHTS 10 VINTAGE BAUBLES
# InvoiceNo C537251 had a total quantity returned of 7 items.
# Description: 10 COLOUR SPACEBOY PEN
# InvoiceNo C537251 had a total quantity returned of 2 items.
# Description: PAPER CHAIN KIT LONDON
# InvoiceNo C537251 had a total quantity returned of 5 items.
# Description: FELTCRAFT CHRISTMAS FAIRY
# InvoiceNo C537251 had a total quantity returned of 8 items.
# Description: CHRISTMAS CRAFT TREE TOP ANGEL
# InvoiceNo C537251 had a total quantity returned of 2 items.
# Description: ROUND SNACK BOXES SET OF 4 FRUITS
# InvoiceNo C537251 had a total quantity returned of 11 items.
# Description: MAGIC DRAWING SLATE PURDEY
# InvoiceNo C537251 had a total quantity returned of 4 items.
# Description: EIGHT PIECE DINOSAUR SET
# InvoiceNo C537251 had a total quantity returned of 3 items.
# Description: FAIRY TALE COTTAGE NIGHTLIGHT
# InvoiceNo C537314 had a total quantity returned of 4 items.
# Description: IVY HEART WREATH
# InvoiceNo C537320 had a total quantity returned of 1 items.
# Description: WOODEN BOX ADVENT CALENDAR
# InvoiceNo C537333 had a total quantity returned of 4 items.
# Description: CHILDS BREAKFAST SET CIRCUS PARADE
# InvoiceNo C537373 had a total quantity returned of 1 items.
# Description: REGENCY CAKESTAND 3 TIER
# InvoiceNo C537379 had a total quantity returned of 10 items.
# Description: HAND WARMER OWL DESIGN
# InvoiceNo C537383 had a total quantity returned of 1 items.
# Description: GLASS  BEURRE DISH
# InvoiceNo C537383 had a total quantity returned of 1 items.
# Description: SMALL POPCORN HOLDER
# InvoiceNo C537383 had a total quantity returned of 1 items.
# Description: AIRLINE BAG VINTAGE TOKYO 78
# InvoiceNo C537398 had a total quantity returned of 1 items.
# Description: ENAMEL WATERING CAN CREAM
# InvoiceNo C537402 had a total quantity returned of 4 items.
# Description: IVORY GIANT GARDEN THERMOMETER
# InvoiceNo C537402 had a total quantity returned of 4 items.
# Description: GREEN GIANT GARDEN THERMOMETER
# InvoiceNo C537402 had a total quantity returned of 4 items.
# Description: BREAD BIN DINER STYLE MINT
# InvoiceNo C537402 had a total quantity returned of 4 items.
# Description: BREAD BIN DINER STYLE IVORY
# InvoiceNo C537402 had a total quantity returned of 6 items.
# Description: TEA TIME DES TEA COSY
# InvoiceNo C537402 had a total quantity returned of 12 items.
# Description: SMALL HEART MEASURING SPOONS
# InvoiceNo C537406 had a total quantity returned of 4 items.
# Description: IVORY GIANT GARDEN THERMOMETER
# InvoiceNo C537406 had a total quantity returned of 4 items.
# Description: GREEN GIANT GARDEN THERMOMETER
# InvoiceNo C537406 had a total quantity returned of 4 items.
# Description: BREAD BIN DINER STYLE IVORY
# InvoiceNo C537406 had a total quantity returned of 4 items.
# Description: BREAD BIN DINER STYLE MINT
# InvoiceNo C537408 had a total quantity returned of 6 items.
# Description: TEA TIME DES TEA COSY
# InvoiceNo C537408 had a total quantity returned of 12 items.
# Description: SMALL HEART MEASURING SPOONS
# InvoiceNo C537413 had a total quantity returned of 72 items.
# Description: HAND WARMER BABUSHKA DESIGN
# InvoiceNo C537414 had a total quantity returned of 1 items.
# Description: POSTAGE
# InvoiceNo C537414 had a total quantity returned of 6 items.
# Description: PAPER CHAIN KIT 50'S CHRISTMAS
# InvoiceNo C537416 had a total quantity returned of 1 items.
# Description: ROUND CAKE TIN VINTAGE RED
# InvoiceNo C537417 had a total quantity returned of 1 items.
# Description: JAM MAKING SET WITH JARS
# InvoiceNo C537431 had a total quantity returned of 1 items.
# Description: LOVE BUILDING BLOCK WORD
# InvoiceNo C537444 had a total quantity returned of 8 items.
# Description: ADVENT CALENDAR GINGHAM SACK
# InvoiceNo C537445 had a total quantity returned of 11 items.
# Description: 10 COLOUR SPACEBOY PEN
# InvoiceNo C537530 had a total quantity returned of 1 items.
# Description: RED RETROSPOT TRADITIONAL TEAPOT
# InvoiceNo C537530 had a total quantity returned of 2 items.
# Description: WHITE BEADED GARLAND STRING 20LIGHT
# InvoiceNo C537530 had a total quantity returned of 2 items.
# Description: ALARM CLOCK BAKELIKE GREEN
# InvoiceNo C537572 had a total quantity returned of 1 items.
# Description: Bank Charges
# InvoiceNo C537581 had a total quantity returned of 1 items.
# Description: SAMPLES
# InvoiceNo C537581 had a total quantity returned of 1 items.
# Description: SAMPLES
# InvoiceNo C537596 had a total quantity returned of 2 items.
# Description: ROSE COTTAGE KEEPSAKE BOX
# InvoiceNo C537597 had a total quantity returned of 1 items.
# Description: Discount
# InvoiceNo C537600 had a total quantity returned of 1 items.
# Description: AMAZON FEE
# InvoiceNo C537602 had a total quantity returned of 1 items.
# Description: JUMBO BAG RED RETROSPOT
# InvoiceNo C537602 had a total quantity returned of 1 items.
# Description: VINTAGE UNION JACK CUSHION COVER
# InvoiceNo C537602 had a total quantity returned of 1 items.
# Description: CHRISTMAS PUDDING TRINKET POT
# InvoiceNo C537602 had a total quantity returned of 1 items.
# Description: LARGE CAKE STAND  HANGING STRAWBERY
# InvoiceNo C537602 had a total quantity returned of 1 items.
# Description: DELUXE SEWING KIT
# InvoiceNo C537602 had a total quantity returned of 1 items.
# Description: WHITE HANGING HEART T-LIGHT HOLDER
# InvoiceNo C537602 had a total quantity returned of 1 items.
# Description: RECIPE BOX BLUE SKETCHBOOK DESIGN
# InvoiceNo C537602 had a total quantity returned of 1 items.
# Description: SMALL POPCORN HOLDER
# InvoiceNo C537602 had a total quantity returned of 4 items.
# Description: LUNCH BOX I LOVE LONDON
# InvoiceNo C537602 had a total quantity returned of 1 items.
# Description: FAMILY ALBUM WHITE PICTURE FRAME
# InvoiceNo C537602 had a total quantity returned of 1 items.
# Description: RED RETROSPOT CAKE STAND
# InvoiceNo C537602 had a total quantity returned of 2 items.
# Description: REGENCY CAKESTAND 3 TIER
# InvoiceNo C537602 had a total quantity returned of 1 items.
# Description: PINK HEART SHAPE EGG FRYING PAN
# InvoiceNo C537602 had a total quantity returned of 1 items.
# Description: LARGE POPCORN HOLDER
# InvoiceNo C537610 had a total quantity returned of 1 items.
# Description: Manual
# InvoiceNo C537611 had a total quantity returned of 36 items.
# Description: HAND WARMER OWL DESIGN
# InvoiceNo C537613 had a total quantity returned of 1 items.
# Description: Manual
# InvoiceNo C537630 had a total quantity returned of 1 items.
# Description: AMAZON FEE
# InvoiceNo C537644 had a total quantity returned of 1 items.
# Description: AMAZON FEE
# InvoiceNo C537647 had a total quantity returned of 1 items.
# Description: AMAZON FEE
# InvoiceNo C537651 had a total quantity returned of 1 items.
# Description: AMAZON FEE
# InvoiceNo C537652 had a total quantity returned of 1 items.
# Description: AMAZON FEE
# InvoiceNo C537656 had a total quantity returned of 12 items.
# Description: VICTORIAN SEWING BOX LARGE
# InvoiceNo C537677 had a total quantity returned of 1 items.
# Description: COOK WITH WINE METAL SIGN
# InvoiceNo C537684 had a total quantity returned of 1 items.
# Description: COFFEE MUG CAT + BIRD DESIGN
# InvoiceNo C537684 had a total quantity returned of 1 items.
# Description: ALARM CLOCK BAKELIKE IVORY
# InvoiceNo C537746 had a total quantity returned of 1 items.
# Description: HEART DECORATION WITH PEARLS
# InvoiceNo C537746 had a total quantity returned of 1 items.
# Description: SKULL LUNCH BOX WITH CUTLERY
# InvoiceNo C537746 had a total quantity returned of 1 items.
# Description: COLOUR GLASS. STAR T-LIGHT HOLDER
# InvoiceNo C537756 had a total quantity returned of 24 items.
# Description: BLUE HARMONICA IN BOX
# InvoiceNo C537756 had a total quantity returned of 8 items.
# Description: SILVER HANGING T-LIGHT HOLDER
# InvoiceNo C537756 had a total quantity returned of 4 items.
# Description: ZINC TOP  2 DOOR WOODEN SHELF
# InvoiceNo C537763 had a total quantity returned of 1 items.
# Description: CREAM SWEETHEART SHELF + HOOKS
# InvoiceNo C537788 had a total quantity returned of 1 items.
# Description: CARNIVAL BRACELET
# InvoiceNo C537788 had a total quantity returned of 1 items.
# Description: BLACK PHOTO ALBUM
# InvoiceNo C537797 had a total quantity returned of 1 items.
# Description: PICNIC BASKET WICKER LARGE
# InvoiceNo C537797 had a total quantity returned of 2 items.
# Description: REGENCY CAKESTAND 3 TIER
# InvoiceNo C537797 had a total quantity returned of 1 items.
# Description: HEART OF WICKER SMALL
# InvoiceNo C537798 had a total quantity returned of 1 items.
# Description: KINGS CHOICE BISCUIT TIN
# InvoiceNo C537805 had a total quantity returned of 1 items.
# Description: SET OF 3 COLOURED  FLYING DUCKS
# InvoiceNo C537805 had a total quantity returned of 2 items.
# Description: WHITE BAMBOO RIBS LAMPSHADE
# InvoiceNo C537805 had a total quantity returned of 1 items.
# Description: WHITE BEADED GARLAND STRING 20LIGHT
# InvoiceNo C537805 had a total quantity returned of 3 items.
# Description: GUMBALL MONOCHROME COAT RACK
# InvoiceNo C537805 had a total quantity returned of 4 items.
# Description: CLEAR MILKSHAKE GLASS
# InvoiceNo C537805 had a total quantity returned of 1 items.
# Description: LARGE POPCORN HOLDER
# InvoiceNo C537805 had a total quantity returned of 1 items.
# Description: SMALL POPCORN HOLDER
# InvoiceNo C537805 had a total quantity returned of 1 items.
# Description: GLITTER HANGING BUTTERFLY STRING
# InvoiceNo C537805 had a total quantity returned of 1 items.
# Description: ROCKING HORSE RED CHRISTMAS
# InvoiceNo C537807 had a total quantity returned of 5 items.
# Description: SILVER HANGING T-LIGHT HOLDER
# InvoiceNo C537807 had a total quantity returned of 3 items.
# Description: GLASS STAR FROSTED T-LIGHT HOLDER
# InvoiceNo C537807 had a total quantity returned of 1 items.
# Description: ANTIQUE GLASS HEART DECORATION
# InvoiceNo C537807 had a total quantity returned of 6 items.
# Description: GARLAND WITH HEARTS AND BELLS
# InvoiceNo C537812 had a total quantity returned of 10 items.
# Description: RED RETROSPOT CAKE STAND
# InvoiceNo C537812 had a total quantity returned of 10 items.
# Description: REGENCY CAKESTAND 3 TIER
# InvoiceNo C537814 had a total quantity returned of 3 items.
# Description: BLUE PADDED SOFT MOBILE
# InvoiceNo C537820 had a total quantity returned of 1 items.
# Description: MINT KITCHEN SCALES
# InvoiceNo C537821 had a total quantity returned of 3 items.
# Description: 15CM CHRISTMAS GLASS BALL 20 LIGHTS
# InvoiceNo C537824 had a total quantity returned of 1 items.
# Description: CAKE STAND LOVEBIRD 2 TIER WHITE
# InvoiceNo C537824 had a total quantity returned of 1 items.
# Description: LANTERN CREAM GAZEBO
# InvoiceNo C537832 had a total quantity returned of 2 items.
# Description: RED RETROSPOT STORAGE JAR
# InvoiceNo C537832 had a total quantity returned of 4 items.
# Description: RED RETROSPOT SUGAR JAM BOWL
# InvoiceNo C537832 had a total quantity returned of 2 items.
# Description: RED RETROSPOT TRADITIONAL TEAPOT
# InvoiceNo C537834 had a total quantity returned of 1 items.
# Description: GREEN REGENCY TEACUP AND SAUCER
# InvoiceNo C537834 had a total quantity returned of 1 items.
# Description: SMALL GLASS HEART TRINKET POT
# InvoiceNo C537834 had a total quantity returned of 3 items.
# Description: ANTIQUE GLASS DRESSING TABLE POT
# InvoiceNo C537835 had a total quantity returned of 3 items.
# Description: BAKING SET 9 PIECE RETROSPOT
# InvoiceNo C537838 had a total quantity returned of 4 items.
# Description: PIG KEYRING WITH LIGHT & SOUND
# InvoiceNo C537853 had a total quantity returned of 1 items.
# Description: MOROCCAN TEA GLASS
# InvoiceNo C537853 had a total quantity returned of 1 items.
# Description: FELTCRAFT CHRISTMAS FAIRY
# InvoiceNo C537853 had a total quantity returned of 2 items.
# Description: FAMILY ALBUM WHITE PICTURE FRAME
# InvoiceNo C537853 had a total quantity returned of 1 items.
# Description: GREEN REGENCY TEACUP AND SAUCER
# InvoiceNo C537853 had a total quantity returned of 2 items.
# Description: JAM MAKING SET WITH JARS
# InvoiceNo C537856 had a total quantity returned of 2 items.
# Description: RETRO COFFEE MUGS ASSORTED
# InvoiceNo C537856 had a total quantity returned of 1 items.
# Description: RED RETROSPOT CAKE STAND
# InvoiceNo C537857 had a total quantity returned of 1 items.
# Description: Discount
# InvoiceNo C537860 had a total quantity returned of 8 items.
# Description: CREAM CUPID HEARTS COAT HANGER
# InvoiceNo C537860 had a total quantity returned of 12 items.
# Description: HEART FILIGREE DOVE LARGE
# InvoiceNo C537860 had a total quantity returned of 2 items.
# Description: RED DINER WALL CLOCK
# InvoiceNo C537860 had a total quantity returned of 1 items.
# Description: RETROSPOT LAMP
# InvoiceNo C537860 had a total quantity returned of 3 items.
# Description: VINTAGE UNION JACK DOORSTOP
# InvoiceNo C537860 had a total quantity returned of 3 items.
# Description: RETROSPOT HEART HOT WATER BOTTLE
# InvoiceNo C537860 had a total quantity returned of 6 items.
# Description: VINTAGE NOTEBOOK PARIS DAYS
# InvoiceNo C537860 had a total quantity returned of 12 items.
# Description: RETRO COFFEE MUGS ASSORTED
# InvoiceNo C537860 had a total quantity returned of 25 items.
# Description: WRAP CHRISTMAS SCREEN PRINT
# InvoiceNo C537860 had a total quantity returned of 4 items.
# Description: BINGO SET
# InvoiceNo C537860 had a total quantity returned of 8 items.
# Description: BLUE POLKADOT CUP
# InvoiceNo C537860 had a total quantity returned of 12 items.
# Description: VINTAGE RED MUG
# InvoiceNo C537860 had a total quantity returned of 8 items.
# Description: BLUE POLKADOT BOWL
# InvoiceNo C537860 had a total quantity returned of 2 items.
# Description: BLUE DINER WALL CLOCK
# InvoiceNo C537860 had a total quantity returned of 8 items.
# Description: BLUE POLKADOT PLATE
# InvoiceNo C537860 had a total quantity returned of 8 items.
# Description: RED RETROSPOT PLATE
# InvoiceNo C537860 had a total quantity returned of 8 items.
# Description: RED RETROSPOT BOWL
# InvoiceNo C537860 had a total quantity returned of 10 items.
# Description: RETRO MOD TRAY
# InvoiceNo C537860 had a total quantity returned of 6 items.
# Description: PIGGY BANK RETROSPOT
# InvoiceNo C537860 had a total quantity returned of 4 items.
# Description: DOORSTOP RETROSPOT HEART
# InvoiceNo C537860 had a total quantity returned of 8 items.
# Description: RED RETROSPOT CUP
# InvoiceNo C537893 had a total quantity returned of 1 items.
# Description: SILK PURSE BABUSHKA BLUE
# InvoiceNo C537893 had a total quantity returned of 2 items.
# Description: CHILDS BREAKFAST SET SPACEBOY
# InvoiceNo C537893 had a total quantity returned of 2 items.
# Description: DOLLY GIRL LUNCH BOX
# InvoiceNo C537998 had a total quantity returned of 4 items.
# Description: ALARM CLOCK BAKELIKE RED
# InvoiceNo C537998 had a total quantity returned of 4 items.
# Description: ALARM CLOCK BAKELIKE CHOCOLATE
# InvoiceNo C538052 had a total quantity returned of 1 items.
# Description: BAKING SET 9 PIECE RETROSPOT
# InvoiceNo C538059 had a total quantity returned of 12 items.
# Description: SET OF 3 BUTTERFLY COOKIE CUTTERS
# InvoiceNo C538059 had a total quantity returned of 6 items.
# Description: RED RETROSPOT SMALL MILK JUG
# InvoiceNo C538059 had a total quantity returned of 6 items.
# Description: SET/5 RED RETROSPOT LID GLASS BOWLS
# InvoiceNo C538059 had a total quantity returned of 12 items.
# Description: SET OF 3 HEART COOKIE CUTTERS
# InvoiceNo C538059 had a total quantity returned of 2 items.
# Description: DOORMAT WELCOME PUPPIES
# InvoiceNo C538059 had a total quantity returned of 6 items.
# Description: GREEN REGENCY TEACUP AND SAUCER
# InvoiceNo C538059 had a total quantity returned of 2 items.
# Description: DOORMAT NEW ENGLAND
# InvoiceNo C538059 had a total quantity returned of 4 items.
# Description: ALARM CLOCK BAKELIKE RED
# InvoiceNo C538059 had a total quantity returned of 6 items.
# Description: ROSES REGENCY TEACUP AND SAUCER
# InvoiceNo C538059 had a total quantity returned of 6 items.
# Description: PINK REGENCY TEACUP AND SAUCER
# InvoiceNo C538059 had a total quantity returned of 24 items.
# Description: PACK OF 60 DINOSAUR CAKE CASES
# InvoiceNo C538059 had a total quantity returned of 3 items.
# Description: RETROSPOT LARGE MILK JUG
# InvoiceNo C538059 had a total quantity returned of 3 items.
# Description: RED RETROSPOT ROUND CAKE TINS
# InvoiceNo C538059 had a total quantity returned of 12 items.
# Description: SET OF 72 RETROSPOT PAPER  DOILIES
# InvoiceNo C538062 had a total quantity returned of 14 items.
# Description: RETROSPOT TEA SET CERAMIC 11 PC
# InvoiceNo C538062 had a total quantity returned of 4 items.
# Description: ROUND CONTAINER SET OF 5 RETROSPOT
# InvoiceNo C538062 had a total quantity returned of 1 items.
# Description: SET/3 RED GINGHAM ROSE STORAGE BOX
# InvoiceNo C538062 had a total quantity returned of 2 items.
# Description: ORGANISER WOOD ANTIQUE WHITE
# InvoiceNo C538062 had a total quantity returned of 2 items.
# Description: 12 PENCIL SMALL TUBE WOODLAND
# InvoiceNo C538066 had a total quantity returned of 1 items.
# Description: PAPER CHAIN KIT RETROSPOT
# InvoiceNo C538075 had a total quantity returned of 12 items.
# Description: RETROSPOT CANDLE  SMALL
# InvoiceNo C538081 had a total quantity returned of 33 items.
# Description: DOLLY GIRL LUNCH BOX
# InvoiceNo C538082 had a total quantity returned of 20 items.
# Description: UNION JACK FLAG PASSPORT COVER
# InvoiceNo C538083 had a total quantity returned of 3 items.
# Description: JUMBO BAG RED RETROSPOT
# InvoiceNo C538083 had a total quantity returned of 4 items.
# Description: HAND WARMER UNION JACK
# InvoiceNo C538084 had a total quantity returned of 6 items.
# Description: EASTER TIN CHICKS PINK DAISY
# InvoiceNo C538084 had a total quantity returned of 6 items.
# Description: EASTER TIN BUNNY BOUQUET
# InvoiceNo C538085 had a total quantity returned of 1 items.
# Description: WOOD S/3 CABINET ANT WHITE FINISH
# InvoiceNo C538085 had a total quantity returned of 1 items.
# Description: SMALL GLASS HEART TRINKET POT
# InvoiceNo C538085 had a total quantity returned of 1 items.
# Description: WOOD 2 DRAWER CABINET WHITE FINISH
# InvoiceNo C538088 had a total quantity returned of 24 items.
# Description: BLUE NEW BAROQUE CANDLESTICK CANDLE
# InvoiceNo C538089 had a total quantity returned of 1 items.
# Description: PHARMACIE FIRST AID TIN
# InvoiceNo C538091 had a total quantity returned of 2 items.
# Description: WOODEN BOX ADVENT CALENDAR
# InvoiceNo C538098 had a total quantity returned of 1 items.
# Description: ORGANISER WOOD ANTIQUE WHITE
# InvoiceNo C538099 had a total quantity returned of 1 items.
# Description: SET/3 VANILLA SCENTED CANDLE IN BOX
# InvoiceNo C538099 had a total quantity returned of 3 items.
# Description: NATURAL SLATE HEART CHALKBOARD
# InvoiceNo C538100 had a total quantity returned of 12 items.
# Description: PINK FOXGLOVE ARTIIFCIAL FLOWER
# InvoiceNo C538102 had a total quantity returned of 2 items.
# Description: ENCHANTED BIRD COATHANGER 5 HOOK
# InvoiceNo C538103 had a total quantity returned of 2 items.
# Description: CHRISTMAS LIGHTS 10 REINDEER
# InvoiceNo C538105 had a total quantity returned of 1 items.
# Description: BLACK CHAMPAGNE GLASS
# InvoiceNo C538105 had a total quantity returned of 1 items.
# Description: MA CAMPAGNE CUTLERY BOX
# InvoiceNo C538109 had a total quantity returned of 4 items.
# Description: LIGHT GARLAND BUTTERFILES PINK
# InvoiceNo C538109 had a total quantity returned of 1 items.
# Description: 15CM CHRISTMAS GLASS BALL 20 LIGHTS
# InvoiceNo C538110 had a total quantity returned of 144 items.
# Description: STRAWBERRY CERAMIC TRINKET BOX
# InvoiceNo C538111 had a total quantity returned of 24 items.
# Description: ASSORTED CREEPY CRAWLIES
# InvoiceNo C538112 had a total quantity returned of 1 items.
# Description: RED RETROSPOT TEA CUP AND SAUCER
# InvoiceNo C538112 had a total quantity returned of 3 items.
# Description: RECIPE BOX WITH METAL HEART
# InvoiceNo C538114 had a total quantity returned of 1 items.
# Description: ZINC TOP  2 DOOR WOODEN SHELF
# InvoiceNo C538115 had a total quantity returned of 1 items.
# Description: VICTORIAN GLASS HANGING T-LIGHT
# InvoiceNo C538115 had a total quantity returned of 9 items.
# Description: BIRDHOUSE DECORATION MAGIC GARDEN
# InvoiceNo C538115 had a total quantity returned of 12 items.
# Description: JIGSAW RABBIT AND BIRDHOUSE
# InvoiceNo C538115 had a total quantity returned of 12 items.
# Description: JIGSAW TREE WITH WATERING CAN
# InvoiceNo C538118 had a total quantity returned of 1 items.
# Description: PAPER CHAIN KIT VINTAGE CHRISTMAS
# InvoiceNo C538118 had a total quantity returned of 1 items.
# Description: LANTERN CREAM GAZEBO
# InvoiceNo C538118 had a total quantity returned of 1 items.
# Description: CAROUSEL DESIGN WASHBAG
# InvoiceNo C538119 had a total quantity returned of 1 items.
# Description: HAND WARMER UNION JACK
# InvoiceNo C538119 had a total quantity returned of 1 items.
# Description: HAND WARMER OWL DESIGN
# InvoiceNo C538119 had a total quantity returned of 2 items.
# Description: RECIPE BOX WITH METAL HEART
# InvoiceNo C538121 had a total quantity returned of 1 items.
# Description: SAVOY ART DECO CLOCK
# InvoiceNo C538122 had a total quantity returned of 1 items.
# Description: GROW YOUR OWN PLANT IN A CAN
# InvoiceNo C538123 had a total quantity returned of 1 items.
# Description: WOODLAND PARTY BAG + STICKER SET
# InvoiceNo C538123 had a total quantity returned of 1 items.
# Description: RETROSPOT PARTY BAG + STICKER SET
# InvoiceNo C538123 had a total quantity returned of 2 items.
# Description: 36 FOIL HEART CAKE CASES
# InvoiceNo C538124 had a total quantity returned of 4 items.
# Description: Manual
# InvoiceNo C538124 had a total quantity returned of 1 items.
# Description: ROSES REGENCY TEACUP AND SAUCER
# InvoiceNo C538124 had a total quantity returned of 1 items.
# Description: REGENCY CAKESTAND 3 TIER
# InvoiceNo C538164 had a total quantity returned of 1 items.
# Description: SET OF 3 BLACK FLYING DUCKS
# InvoiceNo C538189 had a total quantity returned of 1 items.
# Description: Manual
# InvoiceNo C538314 had a total quantity returned of 47 items.
# Description: FELTCRAFT HAIRBAND PINK AND BLUE
# InvoiceNo C538341 had a total quantity returned of 1 items.
# Description: SET OF 3 BUTTERFLY COOKIE CUTTERS
# InvoiceNo C538341 had a total quantity returned of 36 items.
# Description: SOLDIERS EGG CUP
# InvoiceNo C538341 had a total quantity returned of 12 items.
# Description: SOLDIERS EGG CUP
# InvoiceNo C538341 had a total quantity returned of 12 items.
# Description: CIRCUS PARADE CHILDRENS EGG CUP
# InvoiceNo C538341 had a total quantity returned of 12 items.
# Description: CIRCUS PARADE CHILDRENS EGG CUP
# InvoiceNo C538341 had a total quantity returned of 12 items.
# Description: CIRCUS PARADE CHILDRENS EGG CUP
# InvoiceNo C538341 had a total quantity returned of 18 items.
# Description: CHILDREN'S CIRCUS PARADE MUG
# InvoiceNo C538341 had a total quantity returned of 6 items.
# Description: CHRISTMAS LIGHTS 10 VINTAGE BAUBLES
# InvoiceNo C538341 had a total quantity returned of 96 items.
# Description: SET 7 BABUSHKA NESTING BOXES
# InvoiceNo C538341 had a total quantity returned of 1 items.
# Description: ALARM CLOCK BAKELIKE IVORY
# InvoiceNo C538341 had a total quantity returned of 1 items.
# Description: ALARM CLOCK BAKELIKE IVORY
# InvoiceNo C538341 had a total quantity returned of 1 items.
# Description: ALARM CLOCK BAKELIKE IVORY
# InvoiceNo C538341 had a total quantity returned of 4 items.
# Description: ALARM CLOCK BAKELIKE ORANGE
# InvoiceNo C538341 had a total quantity returned of 1 items.
# Description: ALARM CLOCK BAKELIKE ORANGE
# InvoiceNo C538341 had a total quantity returned of 1 items.
# Description: ALARM CLOCK BAKELIKE PINK
# InvoiceNo C538341 had a total quantity returned of 3 items.
# Description: ALARM CLOCK BAKELIKE PINK
# InvoiceNo C538341 had a total quantity returned of 1 items.
# Description: ALARM CLOCK BAKELIKE RED
# InvoiceNo C538341 had a total quantity returned of 2 items.
# Description: ALARM CLOCK BAKELIKE RED
# InvoiceNo C538341 had a total quantity returned of 2 items.
# Description: ALARM CLOCK BAKELIKE RED
# InvoiceNo C538341 had a total quantity returned of 1 items.
# Description: ALARM CLOCK BAKELIKE RED
# InvoiceNo C538341 had a total quantity returned of 1 items.
# Description: ALARM CLOCK BAKELIKE GREEN
# InvoiceNo C538341 had a total quantity returned of 2 items.
# Description: ALARM CLOCK BAKELIKE GREEN
# InvoiceNo C538341 had a total quantity returned of 3 items.
# Description: ALARM CLOCK BAKELIKE GREEN
# InvoiceNo C538341 had a total quantity returned of 1 items.
# Description: ALARM CLOCK BAKELIKE GREEN
# InvoiceNo C538341 had a total quantity returned of 1 items.
# Description: ALARM CLOCK BAKELIKE CHOCOLATE
# InvoiceNo C538341 had a total quantity returned of 1 items.
# Description: ALARM CLOCK BAKELIKE CHOCOLATE
# InvoiceNo C538341 had a total quantity returned of 3 items.
# Description: ALARM CLOCK BAKELIKE CHOCOLATE
# InvoiceNo C538341 had a total quantity returned of 1 items.
# Description: ALARM CLOCK BAKELIKE CHOCOLATE
# InvoiceNo C538341 had a total quantity returned of 48 items.
# Description: TRADITIONAL KNITTING NANCY
# InvoiceNo C538341 had a total quantity returned of 1 items.
# Description: FELTCRAFT HAIRBAND PINK AND BLUE
# InvoiceNo C538341 had a total quantity returned of 6 items.
# Description: 5 HOOK HANGER RED MAGIC TOADSTOOL
# InvoiceNo C538341 had a total quantity returned of 1 items.
# Description: FOOD CONTAINER SET 3 LOVE HEART
# InvoiceNo C538341 had a total quantity returned of 1 items.
# Description: PAPER CHAIN KIT 50'S CHRISTMAS
# InvoiceNo C538341 had a total quantity returned of 24 items.
# Description: WOODEN BOX OF DOMINOES
# InvoiceNo C538341 had a total quantity returned of 1 items.
# Description: RED TOADSTOOL LED NIGHT LIGHT
# InvoiceNo C538341 had a total quantity returned of 1 items.
# Description: ASSORTED TUTTI FRUTTI LARGE PURSE
# InvoiceNo C538341 had a total quantity returned of 1 items.
# Description: ASSORTED TUTTI FRUTTI HEART BOX
# InvoiceNo C538341 had a total quantity returned of 1 items.
# Description: DOCTOR'S BAG SOFT TOY
# InvoiceNo C538341 had a total quantity returned of 1 items.
# Description: SWIRLY CIRCULAR RUBBERS IN BAG
# InvoiceNo C538344 had a total quantity returned of 12 items.
# Description: HAND WARMER BIRD DESIGN
# InvoiceNo C538350 had a total quantity returned of 1 items.
# Description: WHITE HANGING HEART T-LIGHT HOLDER
# InvoiceNo C538350 had a total quantity returned of 11 items.
# Description: SWEETHEART CERAMIC TRINKET BOX
# InvoiceNo C538350 had a total quantity returned of 3 items.
# Description: RED RETROSPOT PICNIC BAG
# InvoiceNo C538350 had a total quantity returned of 2 items.
# Description: JUMBO BAG TOYS
# InvoiceNo C538350 had a total quantity returned of 2 items.
# Description: JUMBO BAG STRAWBERRY
# InvoiceNo C538350 had a total quantity returned of 1 items.
# Description: JUMBO  BAG BAROQUE BLACK WHITE
# InvoiceNo C538350 had a total quantity returned of 3 items.
# Description: RED RETROSPOT SHOPPER BAG
# InvoiceNo C538350 had a total quantity returned of 12 items.
# Description: JUMBO BAG RED RETROSPOT
# InvoiceNo C538350 had a total quantity returned of 20 items.
# Description: CERAMIC CAKE BOWL + HANGING CAKES
# InvoiceNo C538350 had a total quantity returned of 3 items.
# Description: LUNCH BAG RED RETROSPOT
# InvoiceNo C538350 had a total quantity returned of 3 items.
# Description: LUNCH BAG  BLACK SKULL.
# InvoiceNo C538350 had a total quantity returned of 2 items.
# Description: JUMBO BAG SCANDINAVIAN PAISLEY
# InvoiceNo C538350 had a total quantity returned of 2 items.
# Description: PLEASE ONE PERSON METAL SIGN
# InvoiceNo C538350 had a total quantity returned of 1 items.
# Description: LADIES & GENTLEMEN METAL SIGN
# InvoiceNo C538350 had a total quantity returned of 3 items.
# Description: HOT BATHS METAL SIGN
# InvoiceNo C538350 had a total quantity returned of 2 items.
# Description: COOK WITH WINE METAL SIGN
# InvoiceNo C538350 had a total quantity returned of 1 items.
# Description: GIN + TONIC DIET METAL SIGN
# InvoiceNo C538350 had a total quantity returned of 2 items.
# Description: YOU'RE CONFUSING ME METAL SIGN
# InvoiceNo C538350 had a total quantity returned of 1 items.
# Description: TOILET METAL SIGN
# InvoiceNo C538350 had a total quantity returned of 1 items.
# Description: CHOC TRUFFLE GOLD TRINKET POT
# InvoiceNo C538350 had a total quantity returned of 4 items.
# Description: CERAMIC CAKE DESIGN SPOTTED PLATE
# InvoiceNo C538350 had a total quantity returned of 1 items.
# Description: LAUNDRY 15C METAL SIGN
# InvoiceNo C538350 had a total quantity returned of 15 items.
# Description: HANGING FAIRY CAKE DECORATION
# InvoiceNo C538350 had a total quantity returned of 4 items.
# Description: PINK DOUGHNUT TRINKET POT
# InvoiceNo C538350 had a total quantity returned of 4 items.
# Description: CHRISTMAS PUDDING TRINKET POT
# InvoiceNo C538350 had a total quantity returned of 4 items.
# Description: STRAWBERRY CERAMIC TRINKET BOX
# InvoiceNo C538357 had a total quantity returned of 144 items.
# Description: HANGING FAIRY CAKE DECORATION
# InvoiceNo C538362 had a total quantity returned of 30 items.
# Description: PACK OF 72 RETROSPOT CAKE CASES
# InvoiceNo C538372 had a total quantity returned of 3 items.
# Description: AREA PATROLLED METAL SIGN
# InvoiceNo C538372 had a total quantity returned of 1 items.
# Description: SILVER HANGING T-LIGHT HOLDER
# InvoiceNo C538372 had a total quantity returned of 2 items.
# Description: ANTIQUE SILVER TEA GLASS ETCHED
# InvoiceNo C538373 had a total quantity returned of 12 items.
# Description: HEART CALCULATOR
# InvoiceNo C538375 had a total quantity returned of 1 items.
# Description: CAKE STAND LOVEBIRD 2 TIER WHITE
# InvoiceNo C538376 had a total quantity returned of 1 items.
# Description: LUNCH BAG CARS BLUE
# InvoiceNo C538376 had a total quantity returned of 12 items.
# Description: SET OF SALT AND PEPPER TOADSTOOLS
# InvoiceNo C538377 had a total quantity returned of 1 items.
# Description: MINI CAKE STAND  HANGING STRAWBERY
# InvoiceNo C538377 had a total quantity returned of 1 items.
# Description: CERAMIC CAKE STAND + HANGING CAKES
# InvoiceNo C538463 had a total quantity returned of 1 items.
# Description: CERAMIC CAKE STAND + HANGING CAKES
# InvoiceNo C538463 had a total quantity returned of 1 items.
# Description: MINI CAKE STAND  HANGING STRAWBERY
# InvoiceNo C538500 had a total quantity returned of 2 items.
# Description: WOOD BLACK BOARD ANT WHITE FINISH
# InvoiceNo C538530 had a total quantity returned of 33 items.
# Description: DOLLY GIRL LUNCH BOX
# InvoiceNo C538531 had a total quantity returned of 2 items.
# Description: SET/3 RED GINGHAM ROSE STORAGE BOX
# InvoiceNo C538536 had a total quantity returned of 48 items.
# Description: HAND WARMER BABUSHKA DESIGN
# InvoiceNo C538595 had a total quantity returned of 2 items.
# Description: WOODEN PICTURE FRAME WHITE FINISH
# InvoiceNo C538628 had a total quantity returned of 1 items.
# Description: TOADSTOOL MONEY BOX
# InvoiceNo C538628 had a total quantity returned of 1 items.
# Description: SAVOY ART DECO CLOCK
# InvoiceNo C538632 had a total quantity returned of 1 items.
# Description: REGENCY CAKESTAND 3 TIER
# InvoiceNo C538642 had a total quantity returned of 1 items.
# Description: CHILDS BREAKFAST SET CIRCUS PARADE
# InvoiceNo C538642 had a total quantity returned of 1 items.
# Description: GLASS  BEURRE DISH
# InvoiceNo C538643 had a total quantity returned of 1 items.
# Description: CHILDS BREAKFAST SET CIRCUS PARADE
# InvoiceNo C538643 had a total quantity returned of 1 items.
# Description: GLASS  BEURRE DISH
# InvoiceNo C538647 had a total quantity returned of 1 items.
# Description: GUMBALL MAGAZINE RACK
# InvoiceNo C538647 had a total quantity returned of 1 items.
# Description: GUMBALL COAT RACK
# InvoiceNo C538650 had a total quantity returned of 1 items.
# Description: GLASS CLOCHE SMALL
# InvoiceNo C538650 had a total quantity returned of 1 items.
# Description: VICTORIAN SEWING BOX LARGE
# InvoiceNo C538650 had a total quantity returned of 1 items.
# Description: CERAMIC STRAWBERRY CAKE MONEY BANK
# InvoiceNo C538670 had a total quantity returned of 4 items.
# Description: HOT WATER BOTTLE TEA AND SYMPATHY
# InvoiceNo C538680 had a total quantity returned of 1 items.
# Description: Bank Charges
# InvoiceNo C538681 had a total quantity returned of 1 items.
# Description: Manual
# InvoiceNo C538682 had a total quantity returned of 1 items.
# Description: Manual
# InvoiceNo C538684 had a total quantity returned of 1 items.
# Description: VICTORIAN SEWING BOX LARGE
# InvoiceNo C538684 had a total quantity returned of 1 items.
# Description: WOODEN ADVENT CALENDAR CREAM
# InvoiceNo C538684 had a total quantity returned of 1 items.
# Description: HEART OF WICKER LARGE
# InvoiceNo C538686 had a total quantity returned of 1 items.
# Description: GUMBALL COAT RACK
# InvoiceNo C538690 had a total quantity returned of 1 items.
# Description: RED RETROSPOT TRADITIONAL TEAPOT
# InvoiceNo C538690 had a total quantity returned of 10 items.
# Description: REGENCY CAKESTAND 3 TIER
# InvoiceNo C538691 had a total quantity returned of 2 items.
# Description: CERAMIC HEART FAIRY CAKE MONEY BANK
# InvoiceNo C538692 had a total quantity returned of 1 items.
# Description: ANTIQUE GLASS PEDESTAL BOWL
# InvoiceNo C538692 had a total quantity returned of 1 items.
# Description: HAND OPEN SHAPE DECO.WHITE
# InvoiceNo C538693 had a total quantity returned of 3 items.
# Description: BLACK WINE GLASS
# InvoiceNo C538693 had a total quantity returned of 2 items.
# Description: JAM MAKING SET WITH JARS
# InvoiceNo C538693 had a total quantity returned of 1 items.
# Description: CHRISTMAS LIGHTS 10 SANTAS
# InvoiceNo C538694 had a total quantity returned of 2 items.
# Description: RED RETROSPOT SUGAR JAM BOWL
# InvoiceNo C538695 had a total quantity returned of 1 items.
# Description: SET 2 TEA TOWELS I LOVE LONDON
# InvoiceNo C538696 had a total quantity returned of 1 items.
# Description: FAMILY PHOTO FRAME CORNICE
# InvoiceNo C538698 had a total quantity returned of 24 items.
# Description: 60 CAKE CASES VINTAGE CHRISTMAS
# InvoiceNo C538699 had a total quantity returned of 4 items.
# Description: WOODEN BOX ADVENT CALENDAR
# InvoiceNo C538700 had a total quantity returned of 2 items.
# Description: CREAM SWEETHEART MINI CHEST
# InvoiceNo C538701 had a total quantity returned of 1 items.
# Description: CERAMIC CHERRY CAKE MONEY BANK
# InvoiceNo C538702 had a total quantity returned of 60 items.
# Description: ASSTD DESIGN 3D PAPER STICKERS
# InvoiceNo C538703 had a total quantity returned of 3 items.
# Description: SILVER HANGING T-LIGHT HOLDER
# InvoiceNo C538704 had a total quantity returned of 2 items.
# Description: COOKING SET RETROSPOT
# InvoiceNo C538705 had a total quantity returned of 1 items.
# Description: GLASS  BEURRE DISH
# InvoiceNo C538705 had a total quantity returned of 16 items.
# Description: REGENCY CAKESTAND 3 TIER
# InvoiceNo C538711 had a total quantity returned of 1 items.
# Description: EMBOSSED GLASS TEALIGHT HOLDER
# InvoiceNo C538712 had a total quantity returned of 1 items.
# Description: CHRISTMAS LIGHTS 10 REINDEER
# InvoiceNo C538713 had a total quantity returned of 2 items.
# Description: 3 TIER CAKE TIN RED AND CREAM
# InvoiceNo C538713 had a total quantity returned of 1 items.
# Description: SET 10 LIGHTS NIGHT OWL
# InvoiceNo C538717 had a total quantity returned of 12 items.
# Description: NATURAL SLATE HEART CHALKBOARD
# InvoiceNo C538718 had a total quantity returned of 48 items.
# Description: VICTORIAN GLASS HANGING T-LIGHT
# InvoiceNo C538720 had a total quantity returned of 4 items.
# Description: WHITE METAL LANTERN
# InvoiceNo C538723 had a total quantity returned of 7 items.
# Description: RETROSPOT PARTY BAG + STICKER SET
# InvoiceNo C538723 had a total quantity returned of 5 items.
# Description: RED RETROSPOT TISSUE BOX
# InvoiceNo C538723 had a total quantity returned of 1 items.
# Description: RED RETROSPOT ROUND CAKE TINS
# InvoiceNo C538725 had a total quantity returned of 20 items.
# Description: FRENCH BLUE METAL DOOR SIGN 5
# InvoiceNo C538726 had a total quantity returned of 1 items.
# Description: WOOLLY HAT SOCK GLOVE ADVENT STRING
# InvoiceNo C538734 had a total quantity returned of 2 items.
# Description: SILVER CHRISTMAS TREE BAUBLE STAND
# InvoiceNo C538742 had a total quantity returned of 2 items.
# Description: JUMBO BAG PINK POLKADOT
# InvoiceNo C538745 had a total quantity returned of 1 items.
# Description: CHRISTMAS CRAFT WHITE FAIRY
# InvoiceNo C538749 had a total quantity returned of 1 items.
# Description: SWEETHEART CAKESTAND 3 TIER
# InvoiceNo C538755 had a total quantity returned of 1 items.
# Description: REGENCY CAKESTAND 3 TIER
# InvoiceNo C538763 had a total quantity returned of 8 items.
# Description: PIZZA PLATE IN BOX
# InvoiceNo C538768 had a total quantity returned of 12 items.
# Description: FRENCH BLUE METAL DOOR SIGN No
# InvoiceNo C538768 had a total quantity returned of 24 items.
# Description: SET OF 3 HEART COOKIE CUTTERS
# InvoiceNo C538771 had a total quantity returned of 1 items.
# Description: MIRRORED DISCO BALL
# InvoiceNo C538794 had a total quantity returned of 1 items.
# Description: POTTERING MUG
# InvoiceNo C538798 had a total quantity returned of 4 items.
# Description: HOT WATER BOTTLE TEA AND SYMPATHY
# InvoiceNo C538802 had a total quantity returned of 4 items.
# Description: JAM MAKING SET WITH JARS
# ...
# Description: FELTCRAFT DOLL MOLLY
# InvoiceNo C580918 had a total quantity returned of 24 items.
# Description: RED SPOTTY BISCUIT TIN
# InvoiceNo C580919 had a total quantity returned of 4 items.
# Description: VINTAGE DOILY TRAVEL SEWING KIT
# InvoiceNo C580919 had a total quantity returned of 2 items.
# Description: ANTIQUE HEART SHELF UNIT
# InvoiceNo C580919 had a total quantity returned of 2 items.
# Description: CARD HOLDER LOVE BIRD SMALL
# InvoiceNo C580919 had a total quantity returned of 1 items.
# Description: HEART MINI PORTRAIT FRAME
# InvoiceNo C580919 had a total quantity returned of 6 items.
# Description: PHOTO FRAME LINEN AND LACE SMALL
# InvoiceNo C580919 had a total quantity returned of 1 items.
# Description: SET OF 4 KNICK KNACK TINS DOILY
# InvoiceNo C580919 had a total quantity returned of 8 items.
# Description: PHOTO FRAME CORNICE
# InvoiceNo C580919 had a total quantity returned of 1 items.
# Description: SET OF 3 CAKE TINS PANTRY DESIGN
# InvoiceNo C580919 had a total quantity returned of 1 items.
# Description: CAMOUFLAGE LED TORCH
# InvoiceNo C580919 had a total quantity returned of 1 items.
# Description: ASSORTED TUTTI FRUTTI PEN
# InvoiceNo C580954 had a total quantity returned of 32 items.
# Description: RETROSPOT PARTY BAG + STICKER SET
# InvoiceNo C580954 had a total quantity returned of 6 items.
# Description: WASH BAG VINTAGE ROSE PAISLEY
# InvoiceNo C580954 had a total quantity returned of 42 items.
# Description: PARTY CONES CANDY ASSORTED
# InvoiceNo C580954 had a total quantity returned of 4 items.
# Description: SCOTTIE DOG HOT WATER BOTTLE
# InvoiceNo C580954 had a total quantity returned of 25 items.
# Description: RED GINGHAM ROSE JEWELLERY BOX
# InvoiceNo C580954 had a total quantity returned of 25 items.
# Description: SET3 BOOK BOX GREEN GINGHAM FLOWER
# InvoiceNo C580954 had a total quantity returned of 5 items.
# Description: RED RETROSPOT PLATE
# InvoiceNo C580954 had a total quantity returned of 16 items.
# Description: RED RETROSPOT CUP
# InvoiceNo C580954 had a total quantity returned of 15 items.
# Description: RED RETROSPOT CHILDRENS UMBRELLA
# InvoiceNo C580954 had a total quantity returned of 4 items.
# Description: CHILDRENS CUTLERY POLKADOT PINK
# InvoiceNo C580954 had a total quantity returned of 5 items.
# Description: CHILDRENS CUTLERY POLKADOT BLUE
# InvoiceNo C580954 had a total quantity returned of 6 items.
# Description: CHILDRENS CUTLERY RETROSPOT RED
# InvoiceNo C580954 had a total quantity returned of 9 items.
# Description: CHILDRENS CUTLERY POLKADOT GREEN
# InvoiceNo C580957 had a total quantity returned of 1 items.
# Description: POSTAGE
# InvoiceNo C580966 had a total quantity returned of 12 items.
# Description: HEART WREATH DECORATION WITH BELL
# InvoiceNo C580966 had a total quantity returned of 1 items.
# Description: PARTY CONE CHRISTMAS DECORATION
# InvoiceNo C580966 had a total quantity returned of 2 items.
# Description: SET OF 10 LED DOLLY LIGHTS
# InvoiceNo C580966 had a total quantity returned of 24 items.
# Description: JINGLE BELL HEART DECORATION
# InvoiceNo C580966 had a total quantity returned of 3 items.
# Description: SET 6 PAPER TABLE LANTERN STARS
# InvoiceNo C580966 had a total quantity returned of 4 items.
# Description: RETROSPOT WOODEN HEART DECORATION
# InvoiceNo C580966 had a total quantity returned of 4 items.
# Description: CHRISTMAS RETROSPOT STAR WOOD
# InvoiceNo C580966 had a total quantity returned of 5 items.
# Description: WOODEN HEART CHRISTMAS SCANDINAVIAN
# InvoiceNo C580966 had a total quantity returned of 4 items.
# Description: HEART OF WICKER SMALL
# InvoiceNo C580966 had a total quantity returned of 4 items.
# Description: SMALL GLASS HEART TRINKET POT
# InvoiceNo C580968 had a total quantity returned of 10 items.
# Description: LUNCH BAG PAISLEY PARK
# InvoiceNo C580968 had a total quantity returned of 20 items.
# Description: VINTAGE DOILY JUMBO BAG RED
# InvoiceNo C580968 had a total quantity returned of 20 items.
# Description: JUMBO BAG PAISLEY PARK
# InvoiceNo C580968 had a total quantity returned of 2 items.
# Description: WALL ART 70'S ALPHABET
# InvoiceNo C580968 had a total quantity returned of 4 items.
# Description: WALL ART VILLAGE SHOW
# InvoiceNo C580968 had a total quantity returned of 4 items.
# Description: WALL ART STOP FOR TEA
# InvoiceNo C580968 had a total quantity returned of 3 items.
# Description: WALL ART STOP FOR TEA
# InvoiceNo C580968 had a total quantity returned of 6 items.
# Description: WALL ART ANIMALS AND NATURE
# InvoiceNo C580968 had a total quantity returned of 4 items.
# Description: WALL ART DOG LICENCE
# InvoiceNo C580968 had a total quantity returned of 6 items.
# Description: WALL ART BUFFALO BILL
# InvoiceNo C580968 had a total quantity returned of 6 items.
# Description: WALL ART HORSE & PONY
# InvoiceNo C580968 had a total quantity returned of 6 items.
# Description: WALL ART TREASURE AHOY
# InvoiceNo C580968 had a total quantity returned of 1 items.
# Description: BOTANICAL GARDENS WALL CLOCK
# InvoiceNo C580968 had a total quantity returned of 12 items.
# Description: BOX OF 6 CHRISTMAS CAKE DECORATIONS
# InvoiceNo C580968 had a total quantity returned of 2 items.
# Description: DOORMAT KEEP CALM AND COME IN
# InvoiceNo C580970 had a total quantity returned of 6 items.
# Description: WOODEN ADVENT CALENDAR CREAM
# InvoiceNo C580971 had a total quantity returned of 36 items.
# Description: CRYSTAL STUD EARRINGS ASSORTED COL
# InvoiceNo C580971 had a total quantity returned of 36 items.
# Description: CRYSTAL STUD EARRINGS CLEAR DISPLAY
# InvoiceNo C580971 had a total quantity returned of 250 items.
# Description: OFFICE MUG WARMER PINK
# InvoiceNo C580989 had a total quantity returned of 1 items.
# Description: WOODLAND PARTY BAG + STICKER SET
# InvoiceNo C581009 had a total quantity returned of 1 items.
# Description: Manual
# InvoiceNo C581012 had a total quantity returned of 1 items.
# Description: STRAWBERRY CERAMIC TRINKET POT
# InvoiceNo C581012 had a total quantity returned of 1 items.
# Description: CERAMIC CAKE STAND + HANGING CAKES
# InvoiceNo C581071 had a total quantity returned of 1 items.
# Description: JUMBO  BAG BAROQUE BLACK WHITE
# InvoiceNo C581100 had a total quantity returned of 1 items.
# Description: WOODEN ADVENT CALENDAR CREAM
# InvoiceNo C581106 had a total quantity returned of 1 items.
# Description: LETTER HOLDER HOME SWEET HOME
# InvoiceNo C581117 had a total quantity returned of 1 items.
# Description: SOLDIERS EGG CUP
# InvoiceNo C581117 had a total quantity returned of 1 items.
# Description: JUMBO STORAGE BAG SUKI
# InvoiceNo C581117 had a total quantity returned of 1 items.
# Description: JUMBO BAG RED RETROSPOT
# InvoiceNo C581117 had a total quantity returned of 3 items.
# Description: JUMBO BAG VINTAGE CHRISTMAS
# InvoiceNo C581117 had a total quantity returned of 1 items.
# Description: HAND WARMER OWL DESIGN
# InvoiceNo C581117 had a total quantity returned of 2 items.
# Description: SET OF 4 KNICK KNACK TINS LONDON
# InvoiceNo C581117 had a total quantity returned of 2 items.
# Description: VINTAGE CHRISTMAS STOCKING
# InvoiceNo C581121 had a total quantity returned of 1 items.
# Description: WHEELBARROW FOR CHILDREN
# InvoiceNo C581124 had a total quantity returned of 4 items.
# Description: TOADSTOOL MONEY BOX
# InvoiceNo C581128 had a total quantity returned of 3 items.
# Description: JUMBO BAG RED RETROSPOT
# InvoiceNo C581145 had a total quantity returned of 1 items.
# Description: Manual
# InvoiceNo C581145 had a total quantity returned of 12 items.
# Description: ZINC FOLKART SLEIGH BELLS
# InvoiceNo C581145 had a total quantity returned of 9 items.
# Description: VINTAGE RED ENAMEL TRIM PLATE
# InvoiceNo C581145 had a total quantity returned of 38 items.
# Description: VINTAGE RED TRIM ENAMEL BOWL
# InvoiceNo C581148 had a total quantity returned of 1 items.
# Description: CERAMIC BOWL WITH STRAWBERRY DESIGN
# InvoiceNo C581148 had a total quantity returned of 4 items.
# Description: BISCUIT TIN 50'S CHRISTMAS
# InvoiceNo C581148 had a total quantity returned of 1 items.
# Description: CERAMIC CAKE STAND + HANGING CAKES
# InvoiceNo C581148 had a total quantity returned of 2 items.
# Description: CERAMIC STRAWBERRY DESIGN MUG
# InvoiceNo C581148 had a total quantity returned of 6 items.
# Description: CERAMIC PLATE STRAWBERRY DESIGN
# InvoiceNo C581148 had a total quantity returned of 4 items.
# Description: DANISH ROSE DECORATIVE PLATE
# InvoiceNo C581162 had a total quantity returned of 3 items.
# Description: ANTIQUE SILVER T-LIGHT GLASS
# InvoiceNo C581178 had a total quantity returned of 1 items.
# Description: TOADSTOOL BEDSIDE LIGHT
# InvoiceNo C581178 had a total quantity returned of 1 items.
# Description: VINTAGE DOILY DELUXE SEWING KIT
# InvoiceNo C581228 had a total quantity returned of 6 items.
# Description: REGENCY CAKESTAND 3 TIER
# InvoiceNo C581228 had a total quantity returned of 12 items.
# Description: WHITE ROCKING HORSE HAND PAINTED
# InvoiceNo C581228 had a total quantity returned of 6 items.
# Description: WOODEN FRAME ANTIQUE WHITE
# InvoiceNo C581228 had a total quantity returned of 24 items.
# Description: GUMBALL MAGAZINE RACK
# InvoiceNo C581228 had a total quantity returned of 36 items.
# Description: GUMBALL COAT RACK
# InvoiceNo C581229 had a total quantity returned of 10 items.
# Description: JUMBO BAG RED RETROSPOT
# InvoiceNo C581229 had a total quantity returned of 24 items.
# Description: JUNGLE POPSICLES ICE LOLLY MOULDS
# InvoiceNo C581229 had a total quantity returned of 24 items.
# Description: RETRO PLASTIC ELEPHANT TRAY
# InvoiceNo C581229 had a total quantity returned of 24 items.
# Description: SPACEBOY ROCKET LOLLY MAKERS
# InvoiceNo C581229 had a total quantity returned of 10 items.
# Description: JUMBO BAG 50'S CHRISTMAS
# InvoiceNo C581229 had a total quantity returned of 20 items.
# Description: LUNCH BAG VINTAGE DOILY
# InvoiceNo C581229 had a total quantity returned of 36 items.
# Description: SET OF 5 LUCKY CAT MAGNETS
# InvoiceNo C581229 had a total quantity returned of 12 items.
# Description: CARD DOLLY GIRL
# InvoiceNo C581229 had a total quantity returned of 12 items.
# Description: TEA PARTY BIRTHDAY CARD
# InvoiceNo C581229 had a total quantity returned of 12 items.
# Description: VINTAGE KID DOLLY CARD
# InvoiceNo C581229 had a total quantity returned of 12 items.
# Description: ELEPHANT BIRTHDAY CARD
# InvoiceNo C581235 had a total quantity returned of 1 items.
# Description: SET OF TEA COFFEE SUGAR TINS PANTRY
# InvoiceNo C581235 had a total quantity returned of 2 items.
# Description: ROUND CAKE TIN VINTAGE RED
# InvoiceNo C581235 had a total quantity returned of 2 items.
# Description: DOLLY CABINET 2 DRAWERS
# InvoiceNo C581235 had a total quantity returned of 1 items.
# Description: HEART T-LIGHT HOLDER WILLIE WINKIE
# InvoiceNo C581235 had a total quantity returned of 1 items.
# Description: REGENCY CAKESTAND 3 TIER
# InvoiceNo C581305 had a total quantity returned of 1 items.
# Description: MINT KITCHEN SCALES
# InvoiceNo C581305 had a total quantity returned of 1 items.
# Description: WOOD BLACK BOARD ANT WHITE FINISH
# InvoiceNo C581316 had a total quantity returned of 1 items.
# Description: GLASS  SONGBIRD STORAGE JAR
# InvoiceNo C581316 had a total quantity returned of 1 items.
# Description: RED RETROSPOT SUGAR JAM BOWL
# InvoiceNo C581316 had a total quantity returned of 1 items.
# Description: REGENCY SUGAR BOWL GREEN
# InvoiceNo C581322 had a total quantity returned of 1 items.
# Description: SET OF 20 VINTAGE CHRISTMAS NAPKINS
# InvoiceNo C581322 had a total quantity returned of 1 items.
# Description: RECIPE BOX PANTRY YELLOW DESIGN
# InvoiceNo C581323 had a total quantity returned of 1 items.
# Description: RETROSPOT LARGE MILK JUG
# InvoiceNo C581330 had a total quantity returned of 25 items.
# Description: WRAP CHRISTMAS VILLAGE
# InvoiceNo C581330 had a total quantity returned of 100 items.
# Description: WRAP 50'S  CHRISTMAS
# InvoiceNo C581384 had a total quantity returned of 2 items.
# Description: AFGHAN SLIPPER SOCK PAIR
# InvoiceNo C581390 had a total quantity returned of 3 items.
# Description: RED HANGING HEART T-LIGHT HOLDER
# InvoiceNo C581390 had a total quantity returned of 10 items.
# Description: RED SPOT PAPER GIFT BAG
# InvoiceNo C581393 had a total quantity returned of 3 items.
# Description: LIGHT GARLAND BUTTERFILES PINK
# InvoiceNo C581409 had a total quantity returned of 1 items.
# Description: ANTIQUE SILVER T-LIGHT GLASS
# InvoiceNo C581409 had a total quantity returned of 3 items.
# Description: 36 PENCILS TUBE RED RETROSPOT
# InvoiceNo C581409 had a total quantity returned of 3 items.
# Description: STORAGE TIN HOME SWEET HOME
# InvoiceNo C581409 had a total quantity returned of 2 items.
# Description: GLASS JAR DIGESTIVE BISCUITS
# InvoiceNo C581409 had a total quantity returned of 1 items.
# Description: VINTAGE LEAF CHOPPING BOARD
# InvoiceNo C581409 had a total quantity returned of 1 items.
# Description: SET OF 3 REGENCY CAKE TINS
# InvoiceNo C581409 had a total quantity returned of 1 items.
# Description: ROCOCO WALL MIRROR WHITE
# InvoiceNo C581409 had a total quantity returned of 1 items.
# Description: GUMBALL MAGAZINE RACK
# InvoiceNo C581409 had a total quantity returned of 1 items.
# Description: WOOD BLACK BOARD ANT WHITE FINISH
# InvoiceNo C581409 had a total quantity returned of 1 items.
# Description: WOODEN PICTURE FRAME WHITE FINISH
# InvoiceNo C581409 had a total quantity returned of 2 items.
# Description: METAL 4 HOOK HANGER FRENCH CHATEAU
# InvoiceNo C581409 had a total quantity returned of 1 items.
# Description: LARGE HANGING IVORY & RED WOOD BIRD
# InvoiceNo C581409 had a total quantity returned of 5 items.
# Description: SMALL SQUARE CUT GLASS CANDLESTICK
# InvoiceNo C581460 had a total quantity returned of 5 items.
# Description: POPCORN HOLDER
# InvoiceNo C581460 had a total quantity returned of 1 items.
# Description: PIZZA PLATE IN BOX
# InvoiceNo C581462 had a total quantity returned of 48 items.
# Description: HOUSE SHAPE PENCIL SHARPENER
# InvoiceNo C581462 had a total quantity returned of 72 items.
# Description: ASSORTED TUTTI FRUTTI PEN
# InvoiceNo C581463 had a total quantity returned of 2 items.
# Description: 15CM CHRISTMAS GLASS BALL 20 LIGHTS
# InvoiceNo C581464 had a total quantity returned of 1 items.
# Description: DOLLY CABINET 3 DRAWERS
# InvoiceNo C581464 had a total quantity returned of 6 items.
# Description: COLOURED GLASS STAR T-LIGHT HOLDER
# InvoiceNo C581465 had a total quantity returned of 2 items.
# Description: HENRIETTA HEN MUG
# InvoiceNo C581465 had a total quantity returned of 1 items.
# Description: 3 HOOK PHOTO SHELF ANTIQUE WHITE
# InvoiceNo C581465 had a total quantity returned of 4 items.
# Description: POTTERING MUG
# InvoiceNo C581465 had a total quantity returned of 3 items.
# Description: SET/5 RED RETROSPOT LID GLASS BOWLS
# InvoiceNo C581466 had a total quantity returned of 1 items.
# Description: 3 TIER CAKE TIN RED AND CREAM
# InvoiceNo C581466 had a total quantity returned of 2 items.
# Description: SET OF 3 CAKE TINS PANTRY DESIGN
# InvoiceNo C581466 had a total quantity returned of 1 items.
# Description: SET 3 RETROSPOT TEA,COFFEE,SUGAR
# InvoiceNo C581466 had a total quantity returned of 2 items.
# Description: RED RETROSPOT SMALL MILK JUG
# InvoiceNo C581466 had a total quantity returned of 1 items.
# Description: STRAWBERRY CERAMIC TRINKET POT
# InvoiceNo C581468 had a total quantity returned of 10 items.
# Description: SMALL GLASS HEART TRINKET POT
# InvoiceNo C581468 had a total quantity returned of 12 items.
# Description: BOUDOIR SQUARE TISSUE BOX
# InvoiceNo C581470 had a total quantity returned of 4 items.
# Description: RABBIT NIGHT LIGHT
# InvoiceNo C581484 had a total quantity returned of 80995 items.
# Description: PAPER CRAFT , LITTLE BIRDIE
# InvoiceNo C581490 had a total quantity returned of 12 items.
# Description: VICTORIAN GLASS HANGING T-LIGHT
# InvoiceNo C581490 had a total quantity returned of 11 items.
# Description: ZINC T-LIGHT HOLDER STARS SMALL
# InvoiceNo C581499 had a total quantity returned of 1 items.
# Description: Manual
# InvoiceNo C581568 had a total quantity returned of 5 items.
# Description: VICTORIAN SEWING BOX LARGE
# InvoiceNo C581569 had a total quantity returned of 1 items.
# Description: HANGING HEART JAR T-LIGHT HOLDER
# InvoiceNo C581569 had a total quantity returned of 5 items.
# Description: 36 PENCILS TUBE RED RETROSPOT

# %%
# Load the sales data into a pandas DataFrame
sales_data = pd.read_csv(r"C:\Users\USER\Downloads\Telegram Desktop\OnlineRetail.csv", usecols=['InvoiceNo', 'Description', 'Quantity', 'Country'])

# Filter the DataFrame to only include transactions with negative quantities (returns)
returns_data = sales_data[sales_data['Quantity'] < 0]

# Group the returns data by Country and sum the Quantity column to get the total number of returned items per country
returns_by_country = returns_data.groupby('Country')['Quantity'].sum()

# Count the number of unique countries in the returns data
num_countries = len(returns_data['Country'].unique())

# Print the results
print(f"Items returned by {num_countries} unique countries:")
print(returns_by_country)
# Out:
# Items returned by 30 unique countries:
# Country
# Australia               -556
# Austria                  -54
# Bahrain                  -54
# Belgium                  -85
# Channel Islands          -12
# Cyprus                   -44
# Czech Republic           -79
# Denmark                  -47
# EIRE                   -4810
# European Community        -2
# Finland                  -38
# France                 -1624
# Germany                -1815
# Greece                    -1
# Hong Kong                 -4
# Israel                   -56
# Italy                   -113
# Japan                   -798
# Malta                    -26
# Netherlands             -809
# Norway                   -91
# Poland                   -31
# Portugal                 -78
# Saudi Arabia              -5
# Singapore                 -7
# Spain                  -1127
# Sweden                  -446
# Switzerland             -305
# USA                    -1424
# United Kingdom       -469990
# Name: Quantity, dtype: int64

# %% [markdown]
# ### OBSERVATION
#
# The data shows that items were returned by 30 unique countries, with the United Kingdom having the highest number of returns at -469990 items. Other countries with high returns include Germany (-1815 items), France (-1624 items), Spain (-1127 items), and EIRE (-4810 items). On the other hand, some countries had very low returns, such as Greece (-1 item), European Community (-2 items), and Hong Kong (-4 items).
#
# It is important to investigate why certain countries had higher return rates than others. Possible factors could include differences in customer preferences, shipping times, product quality, or marketing strategies.

# %%
# Identify which items are frequently bought together in large or small quantities
# Group the data by InvoiceNo and calculate the total Quantity for each group
invoice_quantity = df.groupby('InvoiceNo')['Quantity'].sum()

# Print the results
print("Total quantity sold for each InvoiceNo:")
print(invoice_quantity)
# Out:
# Total quantity sold for each InvoiceNo:
# InvoiceNo
# 536365     40.0
# 536366     12.0
# 536367     83.0
# 536368     15.0
# 536369      3.0
#            ...
# C581484     3.0
# C581490     6.0
# C581499     3.0
# C581568     3.0
# C581569     6.0
# Name: Quantity, Length: 25900, dtype: float64

# %% [markdown]
# ###  OBSERVATION
# The analysis revealed that the company had a total of 25,900 unique InvoiceNo transactions. The total quantity sold for each transaction varied widely, with some transactions involving only a few items while others involved dozens or even hundreds of items.
#
# For example, InvoiceNo 536365 had a total quantity sold of 40 items, indicating that this was a relatively large transaction. On the other hand, InvoiceNo 536369 had a total quantity sold of only three items, indicating that this was a relatively small transaction.
#
# Interestingly, some InvoiceNo transactions had negative quantities sold, indicating that the customer returned some items. These transactions were denoted by the letter "C" preceding the InvoiceNo. For example, InvoiceNo C581484 had a total quantity sold of negative three items, indicating that the customer returned three items.

# %%
#  identify patterns in the prices of purchases.
# Group the data by InvoiceNo and calculate the average and total UnitPrice for each group
invoice_prices = df.groupby('InvoiceNo')['UnitPrice'].agg(['mean', 'sum'])

# Print the results
print("Average and total UnitPrice for each InvoiceNo:")
print(invoice_prices)
# Out:
# Average and total UnitPrice for each InvoiceNo:
#                  mean     sum
# InvoiceNo
# 536365       3.910000   27.37
# 536366       1.850000    3.70
# 536367       4.853333   58.24
# 536368       4.775000   19.10
# 536369       5.950000    5.95
# ...               ...     ...
# C581484      2.080000    2.08
# C581490      1.390000    2.78
# C581499    224.690000  224.69
# C581568     10.950000   10.95
# C581569      1.250000    2.50
#
# [25900 rows x 2 columns]

# %% [markdown]
# ### OBSERVATION
#
# The analysis revealed significant variability in both the average and total unit prices across transactions. Some transactions were characterized by a lower average unit price, suggesting customers purchased less expensive items. In contrast, other transactions exhibited a higher average unit price, signifying purchases of more expensive items.
#
# For instance, consider InvoiceNo 536365, which had an average unit price of 3.91 and a total unit price of 27.37, indicating it was a relatively low-cost transaction. Conversely, InvoiceNo C581499 boasted an average unit price of 224.69 and a total unit price of 224.69, marking it as a high-cost transaction.
#  Interestingly, certain transactions displayed negative unit prices, denoted by the letter "C" preceding the InvoiceNo. For example, InvoiceNo C581484 had an average unit price of 2.08 and a total unit price of 2.08, implying that the customer received a discount or refund.

# %%
# identify patterns in the dates of purchases
# Convert the InvoiceDate column to a datetime format
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])

# Group the data by InvoiceNo and calculate the earliest and latest InvoiceDate for each group
invoice_dates = df.groupby('InvoiceNo')['InvoiceDate'].agg(['min', 'max'])

# Print the results
print("Earliest and latest InvoiceDate for each InvoiceNo:")
print(invoice_dates)
# Out:
# Earliest and latest InvoiceDate for each InvoiceNo:
#                           min                 max
# InvoiceNo
# 536365    2010-12-01 08:26:00 2010-12-01 08:26:00
# 536366    2010-12-01 08:28:00 2010-12-01 08:28:00
# 536367    2010-12-01 08:34:00 2010-12-01 08:34:00
# 536368    2010-12-01 08:34:00 2010-12-01 08:34:00
# 536369    2010-12-01 08:35:00 2010-12-01 08:35:00
# ...                       ...                 ...
# C581484   2011-12-09 09:27:00 2011-12-09 09:27:00
# C581490   2011-12-09 09:57:00 2011-12-09 09:57:00
# C581499   2011-12-09 10:28:00 2011-12-09 10:28:00
# C581568   2011-12-09 11:57:00 2011-12-09 11:57:00
# C581569   2011-12-09 11:58:00 2011-12-09 11:58:00
#
# [25900 rows x 2 columns]

# %% [markdown]
# ### OBSERVATION
#
# The data provided shows the earliest and latest invoice dates for each invoice number in the dataset. The earliest and latest dates are represented in the 'min' and 'max' columns, respectively.

# %%
# Identify which customers are making multiple purchases. 
# Group the data by CustomerID and count the number of unique InvoiceNo for each group
customer_purchase_count = df.groupby('CustomerID')['InvoiceNo'].nunique()

# Print the results
print("Number of purchases for each customer:")
print(customer_purchase_count)
# Out:
# Number of purchases for each customer:
# CustomerID
# 12346.0       2
# 12347.0       7
# 12348.0       4
# 12349.0       1
# 12350.0       1
#            ...
# 18281.0       1
# 18282.0       3
# 18283.0      16
# 18287.0       3
# Unknown    3710
# Name: InvoiceNo, Length: 4373, dtype: int64

# %%
# Find the day with the highest revenue.
# Group the data by date and sum the revenue for each day
revenue_by_day = df.groupby('InvoiceDate')['Revenue'].sum()

# Find the date with the highest revenue
highest_revenue_day = revenue_by_day.idxmax()

# Print the results
print('The day with the highest revenue is:', highest_revenue_day)
# Out:
# The day with the highest revenue is: 2011-12-09 09:15:00

# %% [markdown]
# ###  OBSERVATION
#
# The data provided shows that the day with the highest revenue is December 9th, 2011 at 9:15am. This information can provide valuable insights into customer behavior and help businesses optimize their sales strategies.
#
# By analyzing the data, we can identify potential reasons for why this particular day and time had the highest revenue.

# %%
# Calculate the revenue for each product
df['UnitPrice'] * df['Quantity']

# Group the data by product and sum the revenue for each product
revenue_by_product = df.groupby('Description')['Revenue'].sum()

# Sort the products by revenue in descending order and display the top 5 products
top_5_products = revenue_by_product.sort_values(ascending=False).head(5)

# Print the results
print(top_5_products)
# Out:
# Description
# AMAZON FEE                     719605.86
# Manual                         499139.36
# DOTCOM POSTAGE                 206258.64
# REGENCY CAKESTAND 3 TIER       180992.19
# PAPER CRAFT , LITTLE BIRDIE    168475.84
# Name: Revenue, dtype: float64

# %% [markdown]
# ###  OBSERVATION
#
# The data provided shows the top five items by revenue in the dataset. The item with the highest revenue is 'AMAZON FEE', which generated a total revenue of 719,605.86. The second highest revenue item is 'Manual', which generated a total revenue of 499,139.36. The third highest revenue item is 'DOTCOM POSTAGE', which generated a total revenue of 206,258.64. The fourth and fifth highest revenue items are 'REGENCY CAKESTAND 3 TIER' and 'PAPER CRAFT, LITTLE BIRDIE', which generated total revenues of 180,992.19 and 168,475.84, respectively.

# %%
# Create a pie chart for revenue by product
plt.figure(figsize=(8, 8))
plt.pie(top_5_products.values, labels=top_5_products.index, autopct='%1.1f%%', startangle=90)

# Set plot title
plt.title('Revenue by Product')

# Show the plot
plt.tight_layout()
plt.show()

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER       6.0
# 1    536365     71053                  WHITE METAL LANTERN       6.0
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER       8.0
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE       6.0
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.       6.0
#
#           InvoiceDate  UnitPrice CustomerID         Country  Revenue
# 0 2010-12-01 08:26:00       2.55    17850.0  United Kingdom    15.30
# 1 2010-12-01 08:26:00       3.39    17850.0  United Kingdom    20.34
# 2 2010-12-01 08:26:00       2.75    17850.0  United Kingdom    22.00
# 3 2010-12-01 08:26:00       3.39    17850.0  United Kingdom    20.34
# 4 2010-12-01 08:26:00       3.39    17850.0  United Kingdom    20.34

# %%
# Calculate total spending per customer
customer_spending = df.groupby('CustomerID')['Revenue'].sum() 
print(customer_spending)
# Sort the customers by spending in descending order and display the top 10
top_10_customers = customer_spending.sort_values(ascending=False).head(10)
# Out:
# CustomerID
# 12346.0      77186.72
# 12347.0       4310.00
# 12348.0       1797.24
# 12349.0       1757.55
# 12350.0        334.40
#               ...
# 18281.0         80.82
# 18282.0        178.92
# 18283.0       2094.88
# 18287.0       1837.28
# Unknown    2600259.55
# Name: Revenue, Length: 4373, dtype: float64

# %% [markdown]
# ### OBSERVATION
#
# The data showed that CustomerID 12346.0 had spent a whopping 77,186.72 with the retailer, making them the retailer's top-spending customer.
#
# The second-highest spender was CustomerID 12347.0, who spent 4,310.00 with the retailer. The third and fourth highest spenders were CustomerID 12348.0 and 12349.0, who spent 1,797.24 and 1,757.55 respectively.
#
# Interestingly, there were many customers who had spent relatively small amounts of money with the retailer. For example, CustomerID 12350.0 had only spent 334.40, and there were many other customers who had spent even less.
#
# However, the retailer also noticed that there was a significant amount of revenue associated with an "Unknown" customer ID. Upon further investigation, the retailer realized that this revenue was associated with orders that did not have a valid customer ID attached to them. These orders represented a significant portion of the retailer's revenue, totaling 2,600,259.55.

# %%
# Top 15 Countries with the revenue
# Group the data by country and sum the revenue for each country
revenue_by_country = df.groupby('Country')['Revenue'].sum()

# Sort the countries by revenue in descending order and display the top 15 countries
top_15_countries = revenue_by_country.sort_values(ascending=False).head(15)

# Print the results
print(top_15_countries)
# Out:
# Country
# United Kingdom    1.022604e+07
# Ireland           3.133257e+05
# Netherlands       2.861808e+05
# Germany           2.412687e+05
# France            2.278327e+05
# Australia         1.398481e+05
# Spain             7.096444e+04
# Singapore         5.775599e+04
# Switzerland       5.762789e+04
# Portugal          4.654756e+04
# Belgium           4.169818e+04
# Norway            3.876521e+04
# Sweden            3.871145e+04
# Japan             3.788932e+04
# Hong Kong         3.241608e+04
# Name: Revenue, dtype: float64

# %% [markdown]
# ## OBSERVATION
#
# United Kingdom generated the highest revenue among all countries, with a total revenue of £10,226,040. Ireland followed with a revenue of £313,325, while Netherlands, Germany, and France also generated significant revenue with £286,180, £241,269, and £227,833 respectively.
#
#  Australia, Spain, Singapore, Switzerland, and Portugal generated moderate revenue ranging from £55,000 to £139,848. Belgium, Norway, Sweden, Japan, and Hong Kong had the lowest revenue among the top 15 countries with a total revenue ranging from £32,416 to £41,698.
#
# The data suggests that the company's operations in the UK are the most profitable among all countries. However, there is potential for growth in other countries such as Ireland and the Netherlands where the company has already generated significant revenue. The company may also consider exploring new opportunities in countries with moderate revenue such as Australia and Spain.

# %%
# Group the data by country and sum the revenue for each country
revenue_by_country = df.groupby('Country')['Revenue'].sum()

# Sort the countries by revenue in descending order and display the top 15 countries
top_15_countries = revenue_by_country.sort_values(ascending=False).head(15)

# Create a bar chart of the revenue by country
plt.bar(top_15_countries.index, top_15_countries.values)

# Set the chart title and axis labels
plt.title('Revenue by Country (Top 15)')
plt.xlabel('Country')
plt.ylabel('Revenue')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=90)

# Display the chart
plt.show()

# %%
# Group the data by product and calculate the total sales volume and average price for each product
sales_by_product = df.groupby(['StockCode', 'Description'])['Quantity', 'Revenue'].agg({'Quantity': 'sum', 'Revenue': 'mean'}).reset_index()

# Sort the products by sales volume in descending order and display the top 10 products
top_10_products_by_sales_volume = sales_by_product.sort_values(by='Quantity', ascending=False).head(10)

# Sort the products by average price in descending order and display the top 10 products
top_10_products_by_average_price = sales_by_product.sort_values(by='Revenue', ascending=False).head(10)

# Create a bar chart of the top 10 products by sales volume
plt.figure(figsize=(10, 6))
plt.bar(top_10_products_by_sales_volume['Description'], top_10_products_by_sales_volume['Quantity'])

# Set the chart title and axis labels
plt.title('Top 10 Products by Sales Volume')
plt.xlabel('Product')
plt.ylabel('Sales Volume')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=90)

# Display the chart
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_8864\269084838.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   sales_by_product = df.groupby(['StockCode', 'Description'])['Quantity', 'Revenue'].agg({'Quantity': 'sum', 'Revenue': 'mean'}).reset_index()

# %%
# Create a bar chart of the top 10 products by average price
plt.bar(top_10_products_by_average_price['Description'], top_10_products_by_average_price['Revenue'])

# Set the chart title and axis labels
plt.title('Top 10 Products by Average Price')
plt.xlabel('Product')
plt.ylabel('Average Price')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=90)

# Display the chart
plt.show()

# %%
# Group the data by country and calculate the total sales volume and revenue for each country
sales_by_country = df.groupby('Country')['Quantity', 'Revenue'].agg({'Quantity': 'sum', 'Revenue': 'sum'}).reset_index()

# Sort the countries by sales volume in descending order and display the top 10 countries
top_10_countries_by_sales_volume = sales_by_country.sort_values(by='Quantity', ascending=False).head(10)

# Sort the countries by revenue in descending order and display the top 10 countries
top_10_countries_by_revenue = sales_by_country.sort_values(by='Revenue', ascending=False).head(10)

# Create a bar chart of the top 10 countries by sales volume
plt.figure(figsize=(10, 6))
plt.bar(top_10_countries_by_sales_volume['Country'], top_10_countries_by_sales_volume['Quantity'])

# Set the chart title and axis labels
plt.title('Top 10 Countries by Sales Volume')
plt.xlabel('Country')
plt.ylabel('Sales Volume')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45)

# Display the chart
plt.show()

# Create a bar chart of the top 10 countries by revenue
plt.figure(figsize=(10, 6))
plt.bar(top_10_countries_by_revenue['Country'], top_10_countries_by_revenue['Revenue'])

# Set the chart title and axis labels
plt.title('Top 10 Countries by Revenue')
plt.xlabel('Country')
plt.ylabel('Revenue')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45)

# Display the chart
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_8864\3857296578.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   sales_by_country = df.groupby('Country')['Quantity', 'Revenue'].agg({'Quantity': 'sum', 'Revenue': 'sum'}).reset_index()

# %% [markdown]
# ### OBSERVATION
#
# The charts illustrate that the United Kingdom had the highest sales volume, which will translate into substantial revenue. Ireland and the Netherlands followed closely in sales volume. In contrast, Spain and Japan recorded the lowest sales volume. Concerning revenue, Switzerland and Portugal ranked at the bottom with the lowest figures.

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER       6.0
# 1    536365     71053                  WHITE METAL LANTERN       6.0
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER       8.0
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE       6.0
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.       6.0
#
#           InvoiceDate  UnitPrice CustomerID         Country  Revenue
# 0 2010-12-01 08:26:00       2.55    17850.0  United Kingdom    15.30
# 1 2010-12-01 08:26:00       3.39    17850.0  United Kingdom    20.34
# 2 2010-12-01 08:26:00       2.75    17850.0  United Kingdom    22.00
# 3 2010-12-01 08:26:00       3.39    17850.0  United Kingdom    20.34
# 4 2010-12-01 08:26:00       3.39    17850.0  United Kingdom    20.34

# %%
# Group the data by customer and calculate the total revenue, order count, and average order value for each customer
customer_data = df.groupby('CustomerID').agg({'Revenue': 'sum', 'InvoiceNo': 'nunique', 'Quantity': 'sum'}).reset_index()
customer_data = customer_data.rename(columns={'InvoiceNo': 'order_count', 'Quantity': 'product_count'})
customer_data['average_order_value'] = customer_data['Revenue'] / customer_data['order_count']
customer_data['average_product_count'] = customer_data['product_count'] / customer_data['order_count']

# Sort the customers by total revenue in descending order and display the top 10 customers
top_10_customers_by_revenue = customer_data.sort_values(by='Revenue', ascending=False).head(10)

# Sort the customers by order count in descending order and display the top 10 customers
top_10_customers_by_order_count = customer_data.sort_values(by='order_count', ascending=False).head(10)

# Create a bar chart of the top 10 customers by revenue
plt.figure(figsize=(10, 6))
sns.barplot(x='CustomerID', y='Revenue', data=top_10_customers_by_revenue)
plt.title('Top 10 Customers by Revenue')
plt.xlabel('Customer ID')
plt.ylabel
# Out:
# <function matplotlib.pyplot.ylabel(ylabel, fontdict=None, labelpad=None, *, loc=None, **kwargs)>

# %%
# Filter the data to only include November and December 2011
df = df[(df['InvoiceDate'] >= '2011-11-01') & (df['InvoiceDate'] <= '2011-12-31')]

# Group the data by date and calculate the total revenue for each day
daily_total_revenue = df.groupby('InvoiceDate')['Revenue'].sum()

# Group the data by week and calculate the average revenue for each week
weekly_average_revenue = df.resample('W', on='InvoiceDate')['Revenue'].mean()

# Group the data by month and calculate the total revenue for each month
monthly_total_revenue = df.resample('M', on='InvoiceDate')['Revenue'].sum()

# Group the data by country and calculate the total revenue for each country
revenue_by_country = df.groupby('Country')['Revenue'].sum()

# Create a line chart of the daily total revenue
plt.figure(figsize=(10, 6))
plt.plot(daily_total_revenue.index, daily_total_revenue.values)
plt.title('Daily Total Revenue - November and December 2011')
plt.xlabel('Date')
plt.ylabel('Revenue')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### OBSERVATION
#
# The chart illustrates that revenue went up in December 2011, reaching 170,000.

# %% [markdown]
# ## Multivariates Analysis

# %%
# Create a pivot table of sales volume by country and product category
sales_by_country_and_category = pd.pivot_table(df, values='Quantity', index='Country', columns='Description', aggfunc='sum')

# Get the top 10 product categories by sales volume
top_10_categories = sales_by_country_and_category.sum().sort_values(ascending=False)[:10].index

# Get the top 10 countries by sales volume
top_10_countries = sales_by_country_and_category.sum(axis=1).sort_values(ascending=False)[:10].index

# Limit the pivot table to the top 10 product categories and top 10 countries
sales_by_country_and_category = sales_by_country_and_category.loc[top_10_countries, top_10_categories]

# Create a heatmap of sales volume by country and product category
plt.figure(figsize=(12, 8))
sns.heatmap(sales_by_country_and_category, cmap='YlGnBu')
plt.title('Sales Volume by Country and Product Category - November and December 2011')
plt.xlabel('Product Category')
plt.ylabel('Country')
plt.show()

# %%
# Extract the date and time components from the 'InvoiceDate' column
df['Date'] = df['InvoiceDate'].dt.date
df['Time'] = df['InvoiceDate'].dt.time

# Group the data by date and calculate the total sales volume for each day
daily_sales_volume = df.groupby('Date')['Quantity'].sum()

# Group the data by week and calculate the average revenue for each week
weekly_average_revenue = df.resample('W', on='InvoiceDate')['Revenue'].mean()

# Group the data by month and calculate the total revenue for each month
monthly_total_revenue = df.resample('M', on='InvoiceDate')['Revenue'].sum()

# Create a line chart of the daily sales volume
plt.figure(figsize=(10, 6))
plt.plot(daily_sales_volume.index, daily_sales_volume.values)
plt.title('Daily Sales Volume')
plt.xlabel('Date')
plt.ylabel('Sales Volume')
plt.xticks(rotation=45)
plt.show()

# Create a line chart of the weekly average revenue
plt.figure(figsize=(10, 6))
plt.plot(weekly_average_revenue.index, weekly_average_revenue.values)
plt.title('Weekly Average Revenue')
plt.xlabel('Week')
plt.ylabel('Revenue')
plt.xticks(rotation=45)
plt.show()

# Create a line chart of the monthly total revenue
plt.figure(figsize=(10, 6))
plt.plot(monthly_total_revenue.index, monthly_total_revenue.values)
plt.title('Monthly Total Revenue')
plt.xlabel('Month')
plt.ylabel('Revenue')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### OBSERVATION
#
# The initial chart illustrates the sales volume for both November and December of 2011. Revenue surpassed 80,000 in December 2011, with a notable increase occurring between December 1st and December 8th, culminating in the highest revenue on December 8th, 2011.
#
# The second chart mirrors these trends on a weekly basis. Revenue began to rise between December 1st and December 5th, following a dip on November 13th, 2011. The week with the highest average revenue was recorded at over 32.5, while the lowest was observed on November 27th, 2011.
#
#
# In terms of total monthly revenue for November and December 2011, the highest figure was achieved on November 29th.

# %%
# determine the long-term value of customers, identify high-value customers, 
# and develop strategies to retain and maximize their value# Calculate revenue per customer.
df['Quantity'] * df['UnitPrice']

# Calculate CLV using the formula: CLV = (Revenue per customer * Average customer lifespan)
# For simplicity, we will assume the average customer lifespan is 3 years
clv = df.groupby('CustomerID')['Revenue'].sum() * 3

# Sort customers by CLV in descending order
clv = clv.sort_values(ascending=False)

# Print the top 10 high-value customers
print(clv.head(10))
# Out:
# CustomerID
# Unknown    1821347.97
# 16446.0     505427.52
# 14096.0     150735.21
# 14646.0     111310.29
# 14911.0      90019.38
# 17450.0      88324.35
# 18102.0      80449.86
# 17511.0      63128.52
# 17389.0      54714.42
# 14088.0      50554.83
# Name: Revenue, dtype: float64

# %% [markdown]
# ###  OBSERVATION
#
# The chart reveals that the top 10 customers were responsible for generating over 5 million in revenue. The highest-spending customer made purchases totaling 1,821,347.97 with the company, followed by the second-highest spender at 505,427.52, and the lowest among the top 10 generated 50,554.83. This underscores the fact that a small group of customers holds significant value for the online store.

# %%
top_10_customers = clv.head(10)

# Extract customer IDs and CLV values
customer_ids = top_10_customers.index
clv_values = top_10_customers.values

# Create a bar chart
plt.figure(figsize=(10, 6))
plt.barh(customer_ids, clv_values, color='skyblue')
plt.xlabel('Customer Lifetime Value (CLV)')
plt.ylabel('Customer ID')
plt.title('Top 10 High-Value Customers by CLV')
plt.gca().invert_yaxis()  # Invert the y-axis to display the highest CLV at the top

# Show the plot
plt.show()
